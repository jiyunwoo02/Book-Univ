# %%
import pandas as pd

df7 = pd.read_excel('건국대.xlsx')

# %%
df7 = df7.drop_duplicates(subset='LABEL-3')

# %%
# '대출횟수'열을 기준으로 내림차순으로 정렬합니다.
df_sorted7 = df7.sort_values('LABEL-8', ascending=False)
# 상위 55개 행을 선택합니다.
top_554 = df_sorted7.head(60)

top_554
# Out:
#      LABEL-1  LABEL-2                                           LABEL-3  \
# 0          1        1                공정하다는 착각 : 능력주의는 모두에게 같은 기회를 제공하는가
# 10         1        1                                불편한 편의점 : 김호연 장편소설
# 1          2        2     물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 23         4        4                                    작별인사 :김영하 장편소설
# 2          3        3                                        창조적 사고와 표현
# 26         7        7                                           대학물리학.2
# 32         3        3                         (Python으로 배우는) 문제해결과 인공지능
# 3          4        4                              불편한 편의점.2 : 김호연 장편소설
# 43         4        4                       저주토끼 :정보라 소설집 =Cursed bunny
# 15         6        6                                 옛이야기와 자기발견의 스토리텔링
# 34         5        5               어른의 어휘력 :말에 품격을 더하고 세상을 올바르게 이해하는 힘
# 16         7        7                                     구의 증명 :최진영 소설
# ...

# %%
# '대출횟수'열을 기준으로 내림차순으로 정렬합니다.
df_sorted4 = df4.sort_values('대출횟수', ascending=False)
# 상위 55개 행을 선택합니다.
top_554 = df_sorted4.head(55)

top_554
# Out:
#       순위                                              서명  \
# 161  162                             (현대 사회의) 성·사랑·에로티시즘
# 165  166                                          빅 히스토리
# 80    81                                   물고기는 존재하지 않는다
# 167  168                                            美學理論
# 204  205                                    화학으로 이루어진 세상
# 44    45                                       최신대학물리학.1
# 43    44                                 (글로벌 시대의) 국제금융론
# 205  206                                    트렌드 코리아.2023
# 100  101                                       중급회계 IFRS
# 63    64                                파친코 : 이민진 장편소설.1
# 62    63                                미시경제학 : 연습문제 해답집
# 171  172                                        삶으로서의 은유
# 0      1             달러구트 꿈 백화점.2, 단골손님을 찾습니다 : 이미예 장편소설
# 46    47               Kreyszig 공업수학.상.상미분방정식·선형대수·벡터미적분
# 187  188                                    헤어질 결심  : 각본
# ...

# %%
# '대출횟수'열을 기준으로 내림차순으로 정렬합니다.
df_sorted = df.sort_values('대출횟수', ascending=False)

# 상위 55개 행을 선택합니다.
top_55 = df_sorted.head(50)

top_55
# Out:
#       순위                                          서명  \
# 40    41                                (플라톤의) 국가·政體
# 200  201                           맥베스 :윌리엄 셰익스피어 희곡
# 160  161                                     러시아의 역사
# 161  162                                부자 아빠 가난한 아빠
# 41    42                돈으로 살 수 없는 것들 :무엇이 가치를 결정하는가
# 183  184                                  (FLEX) 독일어
# 162  163                                  처칠, 끝없는 투쟁
# 164  165               기후 위기와 글로벌 그린 뉴딜 : 인류의 생존 매뉴얼
# 43    44                    국가 간의 정치 :세계평화의 권력이론적 접근
# 44    45                             채식주의자 : 한강 연작소설
# 61    62  바벨탑에 도전한 사나이 =(La) homo kiu defiis babelon
# 20    21   파이썬 for beginner :쉽고 빠르게 익히는 프로그래밍의 기본 원리
# 0      1                              파친코 : 이민진 장편소설
# 168  169                                    가을날의 꿈 외
# 120  121                          지적 대화를 위한 넓고 얕은 지식
# 184  185                 (새로운 유형, 새로운 문제!) 플렉스 :스페인어
# 101  102                                    인도사상의 사색
# ...

# %%
# '대출횟수'열을 기준으로 내림차순으로 정렬합니다.
df_sorted1 = df1.sort_values('대출횟수', ascending=False)

# 상위 55개 행을 선택합니다.
top_551 = df_sorted1.head(55)

top_551
# Out:
#       순위                                              서명  \
# 161  162                             (현대 사회의) 성·사랑·에로티시즘
# 165  166                                          빅 히스토리
# 80    81                                   물고기는 존재하지 않는다
# 167  168                                            美學理論
# 204  205                                    화학으로 이루어진 세상
# 44    45                                       최신대학물리학.1
# 43    44                                 (글로벌 시대의) 국제금융론
# 205  206                                    트렌드 코리아.2023
# 100  101                                       중급회계 IFRS
# 63    64                                파친코 : 이민진 장편소설.1
# 62    63                                미시경제학 : 연습문제 해답집
# 171  172                                        삶으로서의 은유
# 0      1             달러구트 꿈 백화점.2, 단골손님을 찾습니다 : 이미예 장편소설
# 46    47               Kreyszig 공업수학.상.상미분방정식·선형대수·벡터미적분
# 187  188                                    헤어질 결심  : 각본
# ...

# %%
top_55.to_csv('한국외대 50권.csv',index=False)

# %%
top_551.to_csv('한양대 50권.csv',index=False)

# %%
top_554.to_csv('건국대 50권.csv',index=False)
