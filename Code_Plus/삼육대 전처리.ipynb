# %% [markdown]
# # 전처리

# %%
import numpy as np
import pandas as pd
import re
from bs4 import BeautifulSoup
from konlpy.tag import Okt

# %%
# 데이터 불러오기
# 도서 데이터
df= pd.read_excel('삼육대 인기도서 50권.xlsx')

# %%
df= pd.read_excel('삼육대 인기도서 50권.xlsx')
df
# Out:
#     순위                                             도서명  \
# 0    1                             지구에서 한아뿐 : 정세랑 장편소설
# 1    2                  돈의 속성 : 최상위 부자가 말하는 돈에 대한 모든 것
# 2    3                                  (IFRS) 회계원리 2판
# 3    4            달러구트 꿈 백화점 : 주문하신 꿈은 매진입니다: 이미예 장편소설
# 4    5              공정하다는 착각 : 능력주의는 모두에게 같은 기회를 제공하는가
# 5    6                      달러구트 꿈 백화점. 2 , 단골손님을 찾습니다
# 6    7                                         불편한 편의점
# 7    8            부의 추월차선 : 부자들이 말해 주지 않는 진정한 부를 얻는 방법
# 8    9                                          파친코. 1
# 9   10                                      미드나잇 라이브러리
# 10  11                                        정의란 무엇인가
# 11  12                               파친코 : 이민진 장편소설. 2
# 12  13                                     칵테일, 러브, 좀비
# 13  14                     우리가 빛의 속도로 갈 수 없다면 : 김초엽 소설
# 14  15                                  중국을 말한다. 01-15
# 15  16                                      글로벌 경영 제3판
# 16  17                                        지구 끝의 온실
# 17  18                           잃어버린 역사 : 그 회복을 위한 시작
# 18  19                                           마케팅전략
# 19  20                           채식주의자 : 한강 연작소설, 장편소설
# 20  21     지적 대화를 위한 넓고 얕은 지식 : :한 권으로 편안하게 즐기는 지식 여행서
# 21  22                                좋은 음식 올바른 식사 개정판
# 22  23  물고기는 존재하지 않는다 : 상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 23  24                                  아몬드 : 손원평 장편소설
# 24  25                         교육 시설 건축을 위한 설계 디테일 도해집
# 25  26                                        음식과 세계문화
# 26  27                        예술과 환영 : 회화적 재현의 심리학적 연구
# 27  28            부의 추월차선 : 부자들이 말해 주지 않는 진정한 부를 얻는 방법
# 28  29                                        실행에 집중하라
# 29  30                              작별하지 않는다 : 한강 장편소설
# 30  31               한번에 통과하는 논문, : SPSS 결과표 작성과 해석 방법
# 31  32                                  구의 증명 : 최진영 소설
# 32  33                   Harry Potter. 제1권, 마법사의 돌 개정판
# 33  34                               (이공계생을 위한) 확률과 통계
# 34  35                               완전한 행복 : 정유정 장편소설
# 35  36            아들아, 돈 공부해야 한다 : 50억 부자 아빠의 현실 경제 수업
# 36  37                                      총, 균, 쇠 3판
# 37  38                                           미래의 부
# 38  39        플랫폼 레볼루션 : 4차 산업혁명 시대를 지배할 플랫폼 비즈니스 모든 것
# 39  40                                어서 오세요, 휴남동서점입니다
# 40  41                             방금 떠나온 세계 : 김초엽 소설집
# 41  42                                     심리학이란 무엇인가?
# 42  43                                 밝은 밤 : 최은영 장편소설
# 43  44               (미래와 진로를 고민하는) 20대가 준비해야 할 것들 개정판
# 44  45                                           침묵의 봄
# 45  46                 질서 너머 : 인생의 다음 단계로 나아가는 12가지 법칙
# 46  47                                    의약품기기분석학 개정판
# 47  48                                          자본론 공부
# 48  49                (5일만에 합격하는) MOS 2016 엑셀 : Expert
# 49  50       플랫폼 레볼루션 : 4차 산업혁명 시대를 지배할 플랫폼 비즈니스의 모든 것
#
#                           저자            출판사  발행연도  대출횟수  \
# 0                        정세랑             난다  2019    19
# 1                        김승호        스노우폭스북스  2020    19
# 2                        김기동           샘앤북스  2017    18
# 3                        이미예          팩토리나인  2020    18
# 4         Sandel, Michael J.          와이즈베리  2020    17
# 5                        이미예          팩토리나인  2021    16
# 6                        김호연          나무옆의자  2021    15
# 7             DeMarco, M. J.             토트  2022    14
# 8                Lee, Minjin           문학사상  2018    13
# 9                 Haig, Matt          인플루엔셜  2021    13
# 10        Sandel, Michael J.            김영사  2010    12
# 11               Lee, Minjin           문학사상  2018    12
# 12                       조예은           안전가옥  2020    12
# 13                       김초엽             허블  2019    12
# 14                 양산췬 [외]지음      신원문화사: 신원  2008    12
# 15                        이철            학현사  2019    11
# 16                       김초엽         자이언트북스  2021    11
# 17                  노목천연계탐사관            시조사  2003    11
# 18                       박철주             형설  2016    11
# 19                        한강    창비: Changbi  2009    11
# 20                       채사장           한빛비즈  2015    11
# 21           White, Ellen G.            시조사  2009    11
# 22              Miller, Lulu              곰  2021    11
# 23                       손원평             창비  2017    10
# 24      Schittich, Christian        엠지에이치북스  2017    10
# 25                김건희 [외] 지음            파워북  2020    10
# 26           Gombrich, E. H.            열화당  2003     9
# 27               DeMarco, MJ        토트: 북새통  2013     9
# 28            Bossidy, Larry         21세기북스  2004     9
# 29                        한강           문학동네  2021     9
# 30             히든그레이스. 논문통계팀         한빛아카데미  2018     9
# 31                       최진영           은행나무  2015     9
# 32            Rowling, J. K.           문학수첩  2014     8
# 33                       안승철  한빛아카데미: 한빛미디어  2014     8
# 34                       정유정           은행나무  2021     8
# 35                       정선용        알에이치코리아  2021     8
# 36         Diamond, Jared M.           문학사상  2018     8
# 37               Davis, Stan           세종서적  2000     8
# 38  Van Alstyne, Marshall W.             부키  2017     8
# 39                       황보름         클레이하우스  2022     8
# 40                       김초엽            한겨레  2021     8
# 41             Adler, Alfred           스타북스  2011     8
# 42                       최은영           문학동네  2021     8
# 43                       김주형          미래문화사  2021     8
# 44            Carson, Rachel          에코리브르  2011     8
# 45       Peterson, Jordan B.        웅진지식하우스  2021     7
# 46                  약품분석학분과회            동명사  2020     7
# 47                       김수행            돌베개  2014     7
# 48                       김경희  한빛아카데미: 한빛미디어  2017     7
# 49       Parker, Geoffrey G.             부키  2017     7
#
#                                                  카테고리  \
# 0   [<a href="https://www.yes24.com/Main/Book.aspx...
# 1   [<a href="https://www.yes24.com/Main/Book.aspx...
# 2   [<a href="https://www.yes24.com/Main/Book.aspx...
# 3   [<a href="https://www.yes24.com/Main/Book.aspx...
# 4   [<a href="https://www.yes24.com/Main/Book.aspx...
# 5   [<a href="https://www.yes24.com/Main/Book.aspx...
# 6   [<a href="https://www.yes24.com/Main/Book.aspx...
# 7   [<a href="https://www.yes24.com/Main/Book.aspx...
# 8   [<a href="https://www.yes24.com/Main/Book.aspx...
# 9   [<a href="https://www.yes24.com/Main/Book.aspx...
# 10  [<a href="https://www.yes24.com/Main/Book.aspx...
# 11  [<a href="https://www.yes24.com/Main/Book.aspx...
# 12  [<a href="https://www.yes24.com/Main/Book.aspx...
# 13  [<a href="https://www.yes24.com/Main/Book.aspx...
# 14  [<a href="https://www.yes24.com/Main/Book.aspx...
# 15  [<a href="https://www.yes24.com/Main/Book.aspx...
# 16  [<a href="https://www.yes24.com/Main/Book.aspx...
# 17  [<a href="https://www.yes24.com/Main/Book.aspx...
# 18  [<a href="https://www.yes24.com/Main/Book.aspx...
# 19  [<a href="https://www.yes24.com/Main/Book.aspx...
# 20  [<a href="https://www.yes24.com/Main/Book.aspx...
# 21  [<a href="https://www.yes24.com/Main/Book.aspx...
# 22  [<a href="https://www.yes24.com/Main/Book.aspx...
# 23  [<a href="https://www.yes24.com/Main/Book.aspx...
# 24  [<a href="https://www.yes24.com/Main/Book.aspx...
# 25  [<a href="https://www.yes24.com/Main/Book.aspx...
# 26  [<a href="https://www.yes24.com/Main/Book.aspx...
# 27  [<a href="https://www.yes24.com/Main/Book.aspx...
# 28  [<a href="https://www.yes24.com/Main/Book.aspx...
# 29  [<a href="https://www.yes24.com/Main/Book.aspx...
# 30  [<a href="https://www.yes24.com/Main/Book.aspx...
# 31  [<a href="https://www.yes24.com/Main/Book.aspx...
# 32  [<a href="https://www.yes24.com/Main/Book.aspx...
# 33  [<a href="https://www.yes24.com/Main/Book.aspx...
# 34  [<a href="https://www.yes24.com/Main/Book.aspx...
# 35  [<a href="https://www.yes24.com/Main/Book.aspx...
# 36  [<a href="https://www.yes24.com/Main/Book.aspx...
# 37  [<a href="https://www.yes24.com/Main/Book.aspx...
# 38  [<a href="https://www.yes24.com/Main/Book.aspx...
# 39  [<a href="https://www.yes24.com/Main/Book.aspx...
# 40  [<a href="https://www.yes24.com/Main/Book.aspx...
# 41  [<a href="https://www.yes24.com/Main/Book.aspx...
# 42  [<a href="https://www.yes24.com/Main/Book.aspx...
# 43  [<a href="https://www.yes24.com/Main/Book.aspx...
# 44  [<a href="https://www.yes24.com/Main/Book.aspx...
# 45  [<a href="https://www.yes24.com/Main/Book.aspx...
# 46  [<a href="https://www.yes24.com/Main/Book.aspx...
# 47  [<a href="https://www.yes24.com/Main/Book.aspx...
# 48  [<a href="https://www.yes24.com/Main/Book.aspx...
# 49  [<a href="https://www.yes24.com/Main/Book.aspx...
#
#                                                  저자소개  \
# 0   [<span class="author_info info_crop">_x000D_\n...
# 1   [<span class="author_info info_crop">_x000D_\n...
# 2   [<span class="author_info info_crop">_x000D_\n...
# 3   [<span class="author_info info_crop">_x000D_\n...
# 4   [<span class="author_info info_crop">_x000D_\n...
# 5   [<span class="author_info info_crop">_x000D_\n...
# 6   [<span class="author_info info_crop">_x000D_\n...
# 7   [<span class="author_info info_crop">_x000D_\n...
# 8   [<span class="author_info info_crop">_x000D_\n...
# 9   [<span class="author_info info_crop">_x000D_\n...
# 10  [<span class="author_info info_crop">_x000D_\n...
# 11  [<span class="author_info info_crop">_x000D_\n...
# 12  [<span class="author_info info_crop">_x000D_\n...
# 13  [<span class="author_info info_crop">_x000D_\n...
# 14  [<span class="author_info info_crop">_x000D_\n...
# 15                                                NaN
# 16  [<span class="author_info info_crop">_x000D_\n...
# 17                                                NaN
# 18  [<span class="author_info info_crop">_x000D_\n...
# 19  [<span class="author_info info_crop">_x000D_\n...
# 20  [<span class="author_info info_crop">_x000D_\n...
# 21                                                NaN
# 22  [<span class="author_info info_crop">_x000D_\n...
# 23  [<span class="author_info info_crop">_x000D_\n...
# 24                                                NaN
# 25                                                NaN
# 26  [<span class="author_info info_crop">_x000D_\n...
# 27  [<span class="author_info info_crop">_x000D_\n...
# 28  [<span class="author_info info_crop">_x000D_\n...
# 29  [<span class="author_info info_crop">_x000D_\n...
# 30  [<span class="author_info info_crop">_x000D_\n...
# 31  [<span class="author_info info_crop">_x000D_\n...
# 32  [<span class="author_info info_crop">_x000D_\n...
# 33  [<span class="author_info info_crop">_x000D_\n...
# 34  [<span class="author_info info_crop">_x000D_\n...
# 35  [<span class="author_info info_crop">_x000D_\n...
# 36  [<span class="author_info info_crop">_x000D_\n...
# 37  [<span class="author_info info_crop">_x000D_\n...
# 38  [<span class="author_info info_crop">_x000D_\n...
# 39  [<span class="author_info info_crop">_x000D_\n...
# 40  [<span class="author_info info_crop">_x000D_\n...
# 41                                                NaN
# 42  [<span class="author_info info_crop">_x000D_\n...
# 43  [<span class="author_info info_crop">_x000D_\n...
# 44  [<span class="author_info info_crop">_x000D_\n...
# 45  [<span class="author_info info_crop">_x000D_\n...
# 46                                                NaN
# 47  [<span class="author_info info_crop">_x000D_\n...
# 48  [<span class="author_info info_crop">_x000D_\n...
# 49  [<span class="author_info info_crop">_x000D_\n...
#
#                                                   책소개  \
# 0   [<div class="infoWrap_txtInner">\n<textarea cl...
# 1   [<div class="infoWrap_txtInner">\n<textarea cl...
# 2   [<div class="infoWrap_txtInner">\n<textarea cl...
# 3   [<div class="infoWrap_txtInner">\n<textarea cl...
# 4   [<div class="infoWrap_txtInner">\n<textarea cl...
# 5   [<div class="infoWrap_txtInner">\n<textarea cl...
# 6   [<div class="infoWrap_txtInner">\n<textarea cl...
# 7   [<div class="infoWrap_txtInner">\n<textarea cl...
# 8   [<div class="infoWrap_txtInner">\n<textarea cl...
# 9   [<div class="infoWrap_txtInner">\n<textarea cl...
# 10  [<div class="infoWrap_txtInner">\n<textarea cl...
# 11  [<div class="infoWrap_txtInner">\n<textarea cl...
# 12  [<div class="infoWrap_txtInner">\n<textarea cl...
# 13  [<div class="infoWrap_txtInner">\n<textarea cl...
# 14  [<div class="infoWrap_txtInner">\n<textarea cl...
# 15  이 책은 국제경영에 관한 이론서입니다. 국제경영의 기초적이고 전반적인 내용을 학습할...
# 16  [<div class="infoWrap_txtInner">\n<textarea cl...
# 17                                                NaN
# 18  『마케팅전략』은 아커교수와 맥러그린 교수가 공저한 'Strategic Market ...
# 19  [<div class="infoWrap_txtInner">\n<textarea cl...
# 20  [<div class="infoWrap_txtInner">\n<textarea cl...
# 21  현대인을 위한 건강 생활 가이드' 시리즈, 『좋은 음식, 올바른 식사』 제1권. 인...
# 22  [<div class="infoWrap_txtInner">\n<textarea cl...
# 23  [<div class="infoWrap_txtInner">\n<textarea cl...
# 24                                                NaN
# 25  [<div class="infoWrap_txtInner">\n<textarea cl...
# 26  [<div class="infoWrap_txtInner">\n<textarea cl...
# 27  [<div class="infoWrap_txtInner">\n<textarea cl...
# 28  [<div class="infoWrap_txtInner">\n<textarea cl...
# 29  [<div class="infoWrap_txtInner">\n<textarea cl...
# 30  [<div class="infoWrap_txtInner">\n<textarea cl...
# 31  [<div class="infoWrap_txtInner">\n<textarea cl...
# 32  [<div class="infoWrap_txtInner">\n<textarea cl...
# 33  [<div class="infoWrap_txtInner">\n<textarea cl...
# 34  [<div class="infoWrap_txtInner">\n<textarea cl...
# 35  [<div class="infoWrap_txtInner">\n<textarea cl...
# 36  [<div class="infoWrap_txtInner">\n<textarea cl...
# 37  [<div class="infoWrap_txtInner">\n<textarea cl...
# 38  [<div class="infoWrap_txtInner">\n<textarea cl...
# 39  [<div class="infoWrap_txtInner">\n<textarea cl...
# 40  [<div class="infoWrap_txtInner">\n<textarea cl...
# 41  [<div class="infoWrap_txtInner">\n<textarea cl...
# 42  [<div class="infoWrap_txtInner">\n<textarea cl...
# 43  [<div class="infoWrap_txtInner">\n<textarea cl...
# 44  [<div class="infoWrap_txtInner">\n<textarea cl...
# 45  [<div class="infoWrap_txtInner">\n<textarea cl...
# 46  분광분석과 분리분석의 첫 단계로서의 기기분석학\n\n약학교육에 필요한 내용을 의약품...
# 47  [<div class="infoWrap_txtInner">\n<textarea cl...
# 48  [<div class="infoWrap_txtInner">\n<textarea cl...
# 49  [<div class="infoWrap_txtInner">\n<textarea cl...
#
#                                                    목차  \
# 0   [<div class="infoWrap_txt">\n<textarea class="...
# 1   [<div class="infoWrap_txt">\n<textarea class="...
# 2   [<div class="infoWrap_txt">\n<textarea class="...
# 3   [<div class="infoWrap_txt">\n<textarea class="...
# 4   [<div class="infoWrap_txt">\n<textarea class="...
# 5   [<div class="infoWrap_txt">\n<textarea class="...
# 6   [<div class="infoWrap_txt">\n<textarea class="...
# 7   [<div class="infoWrap_txt">\n<textarea class="...
# 8                                                 NaN
# 9                                                 NaN
# 10  [<div class="infoWrap_txt">\n<textarea class="...
# 11                                                NaN
# 12  [<div class="infoWrap_txt">\n<textarea class="...
# 13  [<div class="infoWrap_txt">\n<textarea class="...
# 14  [<div class="infoWrap_txt">\n<textarea class="...
# 15  [<div class="infoWrap_txt">\n<textarea class="...
# 16  [<div class="infoWrap_txt">\n<textarea class="...
# 17  [<div class="infoWrap_txt">\n<textarea class="...
# 18  [<div class="infoWrap_txt">\n<textarea class="...
# 19  [<div class="infoWrap_txt">\n<textarea class="...
# 20  [<div class="infoWrap_txt">\n<textarea class="...
# 21  [<div class="infoWrap_txt">\n<textarea class="...
# 22  [<div class="infoWrap_txt">\n<textarea class="...
# 23                                                NaN
# 24  [<div class="infoWrap_txt">\n<textarea class="...
# 25  [<div class="infoWrap_txt">\n<textarea class="...
# 26  서문\n\n서론 심리학과 양식의 수수께끼\n\n1부 유사성의 한계\n1. 빛으로부터...
# 27  [<div class="infoWrap_txt">\n<textarea class="...
# 28  [<div class="infoWrap_txt">\n<textarea class="...
# 29  [<div class="infoWrap_txt">\n<textarea class="...
# 30  [<div class="infoWrap_txt">\n<textarea class="...
# 31  [<div class="infoWrap_txt">\n<textarea class="...
# 32                                                NaN
# 33  [<div class="infoWrap_txt">\n<textarea class="...
# 34  [<div class="infoWrap_txt">\n<textarea class="...
# 35  [<div class="infoWrap_txt">\n<textarea class="...
# 36  [<div class="infoWrap_txt">\n<textarea class="...
# 37  [<div class="infoWrap_txt">\n<textarea class="...
# 38  [<div class="infoWrap_txt">\n<textarea class="...
# 39  [<div class="infoWrap_txt">\n<textarea class="...
# 40  [<div class="infoWrap_txt">\n<textarea class="...
# 41  [<div class="infoWrap_txt">\n<textarea class="...
# 42  [<div class="infoWrap_txt">\n<textarea class="...
# 43  [<div class="infoWrap_txt">\n<textarea class="...
# 44  [<div class="infoWrap_txt">\n<textarea class="...
# 45  [<div class="infoWrap_txt">\n<textarea class="...
# 46  [<div class="infoWrap_txt">\n<textarea class="...
# 47  [<div class="infoWrap_txt">\n<textarea class="...
# 48  [<div class="infoWrap_txt">\n<textarea class="...
# 49  [<div class="infoWrap_txt">\n<textarea class="...
#
#                                                 출판사서평  \
# 0   [<div class="infoWrap_txt">_x000D_\n점점 줄어드는 페이...
# 1   [<div class="infoWrap_txt">\n<br/>그는 정말 필요한 것을...
# 2   [<div class="infoWrap_txt">\n<b>회계원리</b><br/><...
# 3   [<div class="infoWrap_txt">\n<b>텀블벅 펀딩 1812% 달...
# 4   [<div class="infoWrap_txt">\n<b>능력주의는 공정하게 작동하...
# 5   [<div class="infoWrap_txt">\n<b>1년 내내 베스트셀러 1위...
# 6   [<div class="infoWrap_txt">\n<b>원 플러스 원의 기쁨, 삼...
# 7   [<div class="infoWrap_txt">\n<b>부자 되기 40년 플랜에 ...
# 8   [<div class="infoWrap_txt">\n<b>“회복과 연민에 대한 강력...
# 9   [<div class="infoWrap_txt">_x000D_\n★영국 아마존 종합...
# 10  [<div class="infoWrap_txt">_x000D_\n정의를 둘러싼 위대...
# 11  [<div class="infoWrap_txt">\n<b>“역사는 우리를 저버렸지만...
# 12  [<div class="infoWrap_txt">\n<b>이토록 생생한 어둠</b>...
# 13  [<div class="infoWrap_txt">\n<b>“젊은 소설가의 첫 작품집...
# 14  [<div class="infoWrap_txt">_x000D_\n1. 일반 독자들을...
# 15                                                NaN
# 16  [<div class="infoWrap_txt">\n<b>“악마의 식물이 내 정원에...
# 17                                                NaN
# 18                                                NaN
# 19  [<div class="infoWrap_txt">\n<b>폭력과 아름다움의 처절한 ...
# 20  [<div class="infoWrap_txt">\n<b>200만 부 밀리언셀러 “...
# 21                                                NaN
# 22  [<div class="infoWrap_txt">_x000D_\n《워싱턴포스트》, ...
# 23  [<div class="infoWrap_txt">\n<b>감정을 느끼지 못하는 소년...
# 24                                                NaN
# 25  [<div class="infoWrap_txt">_x000D_\n식생활이란 인간의 ...
# 26  심리학과 철학, 문화사 전반을 가로지르는 곰브리치 미술사 연구의 결정판\n\n“어떤...
# 27  [<div class="infoWrap_txt">\n<b>부자 되기 40년 플랜에 ...
# 28                                                NaN
# 29  [<div class="infoWrap_txt">\n<b>이상하지, 눈은.<br/>...
# 30  [<div class="infoWrap_txt">\n<b>PART 01 _ SPSS...
# 31  [<div class="infoWrap_txt">\n<b>상상을 가능케 하는 사랑<...
# 32  [<div class="infoWrap_txt">\n<b>‘해리 포터 키즈’가 완벽...
# 33                                                NaN
# 34  [<div class="infoWrap_txt">\n<b>“행복은 덧셈이 아니야. ...
# 35  [<div class="infoWrap_txt">\n<b>“경제는 사람 사이에 있다...
# 36  [<div class="infoWrap_txt">\n<b>* 인류 문명의 수수께끼를...
# 37  [<div class="infoWrap_txt">\n<b>석유는 데이터로, 부동산은...
# 38  [<div class="infoWrap_txt">\n<b>세계적인 석학들이 저술한 ...
# 39  [<div class="infoWrap_txt">\n<b>먼저 읽은 독자들의 요청으...
# 40  [<div class="infoWrap_txt">\n<b>“사랑하지만 끝내 이해할 ...
# 41                                                NaN
# 42  [<div class="infoWrap_txt">\n<b>“슬픔을 위로하고 감싸주는...
# 43  [<div class="infoWrap_txt">\n<b>꿈과 현실 사이에서 방황하...
# 44  [<div class="infoWrap_txt">\n<b>세상을 바꾼 인물, 세상을...
# 45  [<div class="infoWrap_txt">\n<b>“이 시대 가장 논쟁적이고...
# 46  의약품 기기분석학으로 분권한 후의 첫 번째 개정\n\n이번 분권 후의 첫 번째 개정...
# 47  [<div class="infoWrap_txt">\n<b>한국 최고의 마르크스 경제...
# 48                                                NaN
# 49  [<div class="infoWrap_txt">\n<b>세계적인 석학들이 저술한 ...
#
#                                                   추천사
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [<div class="infoWrap_txt">_x000D_\n역시 마이클 샌델답...
# 5                                                 NaN
# 6   [<div class="infoWrap_txt">_x000D_\n서울역 홈리스로 지...
# 7   [<div class="infoWrap_txt">_x000D_\n부동산스터디 우석,...
# 8   [<div class="infoWrap_txt">_x000D_\n올해(2017년) ...
# 9                                                 NaN
# 10                                                NaN
# 11  [<div class="infoWrap_txt">_x000D_\n올해(2017년) ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  [<div class="infoWrap_txt">_x000D_\n간절히 원해온 것들...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  [<div class="infoWrap_txt">_x000D_\n[2022 내 맘대...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  [<div class="infoWrap_txt">_x000D_\n부동산스터디 우석,...
# 28                                                NaN
# 29  [<div class="infoWrap_txt">_x000D_\n작가가 소재를 택하...
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  [<div class="infoWrap_txt">_x000D_\n한때 좋은 대학만 ...
# 36                                                NaN
# 37                                                NaN
# 38  [<div class="infoWrap_txt">_x000D_\n20세기 후반에 등...
# 39  [<div class="infoWrap_txt">_x000D_\n[2022 내 맘대...
# 40  [<div class="infoWrap_txt">_x000D_\n김초엽의 눈부신 데...
# 41                                                NaN
# 42  [<div class="infoWrap_txt">_x000D_\n태생지를 빌려 삼천...
# 43  [<div class="infoWrap_txt">_x000D_\n이 책의 추천사를 ...
# 44                                                NaN
# 45  [<div class="infoWrap_txt">_x000D_\n“지금 세상은 조던...
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  [<div class="infoWrap_txt">_x000D_\n20세기 후반에 등...

# %% [markdown]
# # 2 특수문자 및 태그 제거
# # 3 영어 및 숫자 제거

# %%
# 특수 문자, 영어, 숫자, 개행 문자 제거 함수 정의
def remove_special_chars(text):
    if isinstance(text, str):
        soup = BeautifulSoup(text, "html.parser")
        cleaned_text = soup.get_text()
        cleaned_text = re.sub('[^가-힣ㄱ-ㅎㅏ-ㅣ\s]', '', cleaned_text)
        cleaned_text = re.sub('[\r\n]+', ' ', cleaned_text)
        return cleaned_text
    else:
        return text

# 대출 횟수를 제외한 컬럼에 대해서 수행
# 특수 문자, 영어, 숫자, 개행 문자 제거할 컬럼들 리스트
columns_to_clean = ['도서명', '저자', '출판사', '발행연도', '카테고리', '저자소개', '책소개', '목차', '출판사서평', '추천사']

# 각 컬럼에 특수 문자, 영어, 숫자, 개행 문자 제거 적용
for column in columns_to_clean:
    df[column] = df[column].apply(remove_special_chars)

# %% [markdown]
# # 4 토큰화 및 형태소 분석

# %%
# Okt
tokenizer = Okt()

# Tokenization and morphological analysis 함수
def tokenize_and_analyze(text):
    if isinstance(text, str):
        tokens = tokenizer.morphs(text)  # Morphological analysis
        return tokens
    else:
        return []

# 토큰화 및 형태소 분석을 적용할 컬럼들 리스트
columns_to_tokenize = ['도서명', '저자', '출판사', '저자소개', '책소개', '목차', '출판사서평', '추천사']

# 각 컬럼에 토큰화 및 형태소 분석 적용
for column in columns_to_tokenize:
    df[column] = df[column].apply(tokenize_and_analyze)

# %% [markdown]
# # 5  텍스트 임베딩

# %%
from gensim.models import Word2Vec

# %%
columns_to_embedding = ['저자소개', '책소개', '출판사서평', '추천사']

author_model = Word2Vec(df[columns_to_embedding[0]], min_count=1)
bood_model = Word2Vec(df[columns_to_embedding[1]], min_count=1)
publisher_model = Word2Vec(df[columns_to_embedding[2]], min_count=1)
recommend_model = Word2Vec(df[columns_to_embedding[3]], min_count=1)

# %% [markdown]
# # 6 불용어 처리

# %%
import nltk
from nltk.corpus import stopwords

# %%
# 불용어 제거 함수
def remove_stopwords(tokens):
  # 불용어 리스트
  with open('stopwords.txt', 'r', encoding='utf-8') as file:
        korean_stopwords = [line.strip() for line in file]
  filtered_tokens = [token for token in tokens if token not in korean_stopwords]
  return filtered_tokens

# 불용어 제거를 적용할 컬럼
columns_to_clean = ['저자소개', '책소개', '출판사서평', '추천사']

# 컬럼 별로 불용어 제거
for column in columns_to_tokenize:
    df[column] = df[column].apply(remove_stopwords)

# %% [markdown]
# # 7 맞춤법 및 띄어쓰기

# %%
from hanspell import spell_checker

# %%
def preprocess_text(text):
    spelled_text = spell_checker.check(text)
    checked_text = spelled_text.checked
    return checked_text

# %%
# 전처리할 열 목록
columns_to_preprocess = ['저자소개', '책소개', '출판사서평', '추천사']

# %%
# 각 열에 대한 전처리 적용
for column in columns_to_preprocess:
    df[column] = df[column].apply(lambda x: preprocess_text(x) if isinstance(x, str) else x)

# %%
df[columns_to_preprocess]
# Out:
#                                                  저자소개  \
# 0   [서울, 태어났다, 판타스틱, 드림, 드림, 드림, 발표, 하며, 작품, 활동, 시...
# 1   [한인, 기업, 최초, 글로벌, 외식, 그룹, 인, 회장, 이다, 한국, 전, 세계...
# 2   [고려대학교, 경영학, 고려대학교, 대학원, 경영학, 과를, 졸업, 회계학, 전공,...
# 3   [부산, 태어났다, 부산, 대, 재료공학, 공부, 하고, 반도체, 엔지니어, 했다,...
# 4   [이후, 한국, 정의, 열풍, 불러일으켰다, 세, 최연, 소, 하버드, 대학교, 교...
# 5   [부산, 태어났다, 부산, 대, 재료공학, 공부, 하고, 반도체, 엔지니어, 했다,...
# 6   [화만, 화, 소설, 넘나, 들며, 온갖, 이야기, 써, 나가는, 전, 천후, 스토...
# 7   [투자자, 이자, 자수, 성가, 한, 백만장자, 개, 국어, 넘는, 언어, 출, 간...
# 8   [전, 세계, 뜨거운, 관심, 사랑, 받고, 있는, 한국, 계, 미국인, 소설가, ...
# 9   [영국, 요크셔, 출신, 동화작가, 겸, 소설가, 다, 출, 간, 한, 첫, 소설,...
# 10  [이후, 한국, 정의, 열풍, 불러일으켰다, 세, 최연, 소, 하버드, 대학교, 교...
# 11  [전, 세계, 뜨거운, 관심, 사랑, 받고, 있는, 한국, 계, 미국인, 소설가, ...
# 12  [회, 황금가지, 타임, 리프, 공모전, 오버, 랩, 나이프, 나이프, 우수상, 회...
# 13  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 14  [상해, 사회과학, 원, 역사, 연구소, 연구원, 상해시, 중학교, 교사, 길림, ...
# 15                                                 []
# 16  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 17                                                 []
# 18  [일본, 게이오, 대학, 상학, 연, 마케팅, 연구, 하였고, 소, 비시, 장, 에...
# 19  [늦은, 태어났다, 연세대, 국문과, 졸업, 한, 뒤, 문학과사회, 시를, 발표, ...
# 20  [겨울, 출, 간, 한, 첫, 책, 지적, 대화, 위, 한, 넓고, 얕은, 지식, ...
# 21                                                 []
# 22  [방송, 계, 퓰리처상, 불리는, 피버디상, 수상한, 과학, 전, 문, 기자, 넘게...
# 23  [서울, 태어났다, 서강대, 학교, 사회학, 철학, 공부, 했고, 한국, 영화아카데...
# 24                                                 []
# 25                                                 []
# 26  [곰, 브리, 치는, 오스트리아, 빈, 태어났다, 미술사, 박사학위, 취득, 하였고...
# 27  [투자자, 이자, 자수, 성가, 한, 백만장자, 개, 국어, 넘는, 언어, 출, 간...
# 28  [래, 리, 보시, 디, 는, 포춘, 선정, 한, 기술, 제조업, 계, 리더, 인,...
# 29  [늦은, 태어났다, 연세대, 국문과, 졸업, 한, 뒤, 문학과사회, 시를, 발표, ...
# 30  [김성은, 주, 히든, 그레이스, 대표, 현재, 데이터, 분석, 머신, 러닝, 프로...
# 31  [눈, 많이, 내리던, 날, 서울, 태어났다, 낮, 엔, 하고, 밤, 엔, 글, 쓰...
# 32  [새로운, 판매, 기록, 세우고, 수많은, 상, 수상한, 해리, 포터, 시리즈, 작...
# 33  [성균관대, 학교, 수학과, 학사, 석사, 박사, 통계학, 전공, 학위, 취득, 하...
# 34  [소설가, 전남, 함평, 출생, 이다, 대학, 시절, 에는, 국문과, 친구, 소설,...
# 35  [간, 유통업, 계, 종사, 하며, 대기업, 직장인, 살았다, 휴일, 근무, 며, ...
# 36  [미국, 보스턴, 출생, 했다, 록스버리, 라틴, 스쿨, 하버드, 대학교, 졸업, ...
# 37  [글, 쓰기, 시작, 했다, 교육, 자기계발, 인문학, 다양한, 분야, 서른, 권,...
# 38  [보스턴, 대학, 교수, 이며, 매사추세츠, 공과대학, 디지털, 경제, 이니셔티브,...
# 39  [대학, 컴퓨터공학, 전공, 하고, 소프트웨어, 개발자, 했다, 번의, 입사, 퇴사...
# 40  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 41                                                 []
# 42  [삼색, 고양이, 날, 태어나, 삼색, 고양이, 고등어, 고양이, 사는, 소설가, ...
# 43  [고등학교, 시절, 수능, 공부, 하는, 대신, 영어, 공부, 하여, 토익, 성적,...
# 44  [생태학, 시대, 어머니, 이자, 환경, 중요성, 깨워, 준, 레이첼, 카슨, 은,...
# 45  [토론토, 대학교, 심리학, 교수, 임상심리학, 가지, 인생, 법칙, 일약, 베스트...
# 46                                                 []
# 47  [일본, 태어나, 해방, 귀국, 해서, 고등학교, 대구, 살았다, 서울대학교, 상과...
# 48  [현재, 한남, 대학교, 국제, 교육, 센터, 교수, 재직, 중이, 며, 대전, 지...
# 49  [보스턴, 대학, 교수, 이며, 매사추세츠, 공과대학, 디지털, 경제, 이니셔티브,...
#
#                                                   책소개  \
# 0   [창비, 장편소설, 상, 한국, 일보, 문학상, 수상, 작가, 정세랑, 두번째, 장...
# 1   [연속, 최, 장기, 베스트셀러, 만, 깨어있는, 독자, 선택, 한, 경제, 경영,...
# 2   [회계, 원리, 는, 모든, 회계, 기초, 입니다, 본, 서는, 회계, 관, 한, ...
# 3   [여기는, 잠들어야만, 입장, 할, 수, 있는, 달러, 구트, 꿈, 백화점, 입니다...
# 4   [마이클, 샌델, 만의, 신간, 공정하다는, 착각, 출, 간, 샌델, 기울어진, 사...
# 5   [만, 독자, 사로잡은, 달러, 구트, 꿈, 백화점, 두, 번째, 이야기, 어느덧,...
# 6   [최고, 재미, 감동, 선사, 하는, 힐링, 소설, 원조, 주요, 서점, 종합, 베...
# 7   [미국, 아마존, 금융, 사업, 분야, 위, 국내, 유명, 서점, 간, 종합, 베스...
# 8   [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 9   [밤, 시, 죽기, 전, 에만, 열리는, 마법, 도서관, 인생, 두, 번째, 기회,...
# 10  [한국, 정의, 열풍, 불러일으킨, 마이클, 샌델, 은, 구제, 금융, 대리, 출산...
# 11  [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 12  [안전가옥, 쇼트, 시리즈, 두, 번째, 책, 조예은, 작가, 단, 편집, 이다, ...
# 13  [우아한, 계보, 후지, 난, 겨울, 바이오, 센서, 만드는, 과학, 도, 였던, ...
# 14  [총, 권, 구성, 되어, 있으며, 원시, 사회, 에서부터, 청나라, 멸망, 중국,...
# 15  [책, 은, 국제, 경영, 관, 한, 이론, 서, 입니다, 국제, 경영, 기초, 적...
# 16  [김, 초엽, 첫, 장편소설, 간절히, 기다려, 온, 이야기, 이미, 폭넓은, 독자...
# 17                                                 []
# 18  [마케팅, 전략, 은, 커, 교수, 맥러, 그린, 교수, 공저, 한, 번역, 한, ...
# 19  [인터내셔널, 부커상, 산클레멘테, 문학상, 수상작, 전세계, 주목, 한, 한강, ...
# 20  [지적, 대화, 하기, 위해, 서, 깔려, 있어야, 하는, 가장, 기본, 지식, 시...
# 21  [현대인, 위, 한, 건강, 생활, 가이드, 시리즈, 좋은, 음식, 올바른, 식사,...
# 22  [방송, 계, 퓰리처상, 피버디상, 수상자, 룰루, 밀러, 사랑, 혼돈, 과학, 적...
# 23  [공감, 불능, 사회, 차가, 움, 녹이는, 아몬드, 매혹, 적, 인, 문체, 독특...
# 24                                                 []
# 25  [세계, 각국, 음식, 문화, 대한, 연구, 는, 인간, 의식, 구조, 삶, 방식,...
# 26  [번역본, 현대, 시, 지각, 이론, 입, 각하, 회화, 적, 재현, 역사, 심리,...
# 27  [미국, 아마존, 금융, 사업, 분야, 위, 국내, 유명, 서점, 간, 종합, 베스...
# 28  [똑같이, 우수한, 비, 전과, 전략, 수립, 하였음에도, 불구, 하고, 기업, 은...
# 29  [생각, 하면, 견딜, 수, 있나, 가슴, 활활, 일어나는, 불, 없다면, 기어이,...
# 30  [분석, 방법, 결과, 표, 작성, 해석, 방법, 논문, 초심자, 해야, 할, 하지...
# 31  [먼저, 죽는다면나는, 먹을, 거, 래야, 없이도, 죽지, 않고, 살, 수, 있어,...
# 32  [해리, 포터, 세대, 해리, 포터, 세대, 위, 한, 해리, 포터, 세대, 의한,...
# 33  [빅데이터, 시대, 이제, 는, 통계, 적, 사고, 경쟁력, 이다, 는, 살아가면서...
# 34  [다시, 정, 유정, 자기애, 늪, 빠진, 삶은, 위태, 로운, 압도, 적, 서사,...
# 35  [베스트셀러, 아들, 돈, 공부, 해야, 한다, 만, 부, 기념, 골드, 에디, 션...
# 36  [민족, 은, 민족, 정복, 지배, 대상, 전락, 하고, 말았는가, 원주민, 은, ...
# 37  [석유, 는, 데이터, 부동산, 은, 데이터, 센터, 코로나, 가속, 화, 한, 차...
# 38  [차, 산업혁명, 주인공, 은, 플랫폼, 축하, 거나, 활용, 하는, 자가, 될, ...
# 39  [받아들여지고, 있다는, 느낌, 이렇게, 슬프고도, 좋을, 줄, 이야, 브런치, 북...
# 40  [사랑, 입자, 타고, 낯선, 세계, 떠, 도, 는, 경이, 롭고, 아름다운, 우주...
# 41  [옥스퍼드, 대학, 입문, 총서, 시리즈, 심리학, 개론, 서, 두뇌, 대한, 과학...
# 42  [백, 감싸안으며, 이어지는, 사랑, 숨, 기록, 쇼코, 미소, 내게, 무, 해한,...
# 43  [현실, 타협, 하는, 삶, 에서도, 행복, 만드는, 방법, 꿈꾸기에는, 불안하고,...
# 44  [세기, 가장, 큰, 영향력, 미친, 책, 컬, 지는, 침묵, 봄, 개정판, 이다,...
# 45  [피터슨, 돌아왔다, 전, 세계, 젊은이, 열광, 시킨, 인생, 법칙, 완결, 판,...
# 46  [분광분석, 분리, 분석, 첫, 단계, 로서, 기, 기분, 석, 학, 약학, 교육,...
# 47  [한국, 최고, 마르크스, 경제학자, 김수행, 교수, 듣는, 자본론, 특강, 자본론...
# 48  [버전, 담은, 첫, 교재, 강의, 경력, 깊고, 풍부한, 전문, 강, 사진, 시험...
# 49  [차, 산업혁명, 주인공, 은, 플랫폼, 축하, 거나, 활용, 하는, 자가, 될, ...
#
#                                                 출판사서평  \
# 0   [점점, 줄어드는, 페이지, 보며, 아쉬워, 무거워진, 눈꺼풀, 참으며, 책, 읽는...
# 1   [는, 정말, 필요한, 나누려는, 사람, 이다, 최근, 사이, 수만, 명의, 사람,...
# 2   [회계, 원리, 회계, 원리, 는, 모든, 회계, 기초, 입니다, 본, 서는, 회계...
# 3   [텀블벅, 펀딩, 달성, 출, 간, 주, 연속, 종합, 베스트셀러, 위, 독자, 별...
# 4   [능력, 주의, 는, 공정하게, 작동, 하는가, 공정함, 정의, 란, 공식, 은, ...
# 5   [내내, 베스트셀러, 위, 독자, 뽑은, 최고, 힐링, 판타지, 잠들어야만, 입장,...
# 6   [원, 플러스, 원, 기쁨, 삼각김밥, 모양, 슬픔, 만, 원, 번의, 폭소, 터지...
# 7   [부자, 되기, 플랜, 속지, 마라, 지금, 까지의, 부자, 되기, 책, 이야기, ...
# 8   [회복, 연민, 대한, 강력한, 이야기, 버락, 오바마, 미국, 전, 대통령, 전,...
# 9   [영국, 아마존, 종합, 베스트셀러, 위, 미국, 아마존, 뉴욕타임스, 선데이타임스...
# 10  [정의, 둘러싼, 위대한, 철학자, 과의, 대화, 글로벌, 금융, 위기, 이후, 억...
# 11  [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 12  [토록, 생생한, 어둠, 감정, 은, 곧잘, 무시, 당한다, 여성, 이라서, 자식,...
# 13  [젊은, 소설가, 첫, 작품집, 이라고는, 믿기지, 않을, 정도, 매끄럽게, 이어지...
# 14  [일반, 독자, 위, 한, 중국, 역사, 문화, 집대성, 한, 백과사전, 중국, 저...
# 15                                                 []
# 16  [악마, 식물, 내, 정원, 자라고, 있는데, 거, 멸망, 징조, 아니야, 덩굴식물...
# 17                                                 []
# 18                                                 []
# 19  [폭력, 아름다, 움, 처절한, 공존, 새롭게, 읽히는, 한강, 소설, 힘년, 창비...
# 20  [만, 부, 밀리언셀러, 지대, 넓, 얕, 최초, 개정, 증보, 판, 지적, 대화,...
# 21                                                 []
# 22  [워싱턴포스트, 북, 라이엇, 내서, 널퍼, 블릭, 라디오, 시카고, 트리뷴, 스미...
# 23  [감정, 느끼지, 못, 하는, 소년, 특별한, 성장, 아몬드, 주인공, 윤재, 는,...
# 24                                                 []
# 25  [식생활, 이란, 인간, 생활, 중, 생명, 유지, 생체, 활동, 필요한, 영양분,...
# 26  [심리학, 철학, 문, 화사, 전반, 가로지르는, 곰, 브리, 치, 미술사, 연구,...
# 27  [부자, 되기, 플랜, 속지, 마라, 지금, 까지의, 부자, 되기, 책, 이야기, ...
# 28                                                 []
# 29  [이상하지, 눈, 은, 하늘, 저런, 게, 내려오지, 작별, 지, 않는다는, 소설가...
# 30  [논문, 통계, 분석, 기초, 편, 에서는, 통계, 분석, 하기, 전, 알아야, 하...
# 31  [상상, 가능, 케, 하는, 사랑, 그런, 사랑, 가능, 케, 하는, 상상, 여자,...
# 32  [해리, 포터, 키즈, 완벽하게, 구현, 한, 롤링, 마법, 세계, 시대, 가장, ...
# 33                                                 []
# 34  [행복, 은, 덧셈, 아니야, 행복, 은, 뺄셈, 이야, 완전해질, 불행, 가능성,...
# 35  [경제, 는, 사람, 사이, 실생활, 밀착, 형, 경제, 수업, 아들, 돈, 공부,...
# 36  [인류, 문명, 수수께끼, 새로운, 풀어, 낸, 명, 개정, 신판, 특별, 증보, ...
# 37  [석유, 는, 데이터, 부동산, 은, 데이터, 센터, 코로나, 가속, 화, 한, 차...
# 38  [세계, 적, 인, 석, 학, 저술, 한, 플랫폼, 비즈니스, 안내서, 포브스, 선...
# 39  [먼저, 읽은, 독자, 요청, 종이, 책, 다시, 태어난, 소설, 출, 간, 전자책...
# 40  [사랑, 끝내, 이해, 할, 수, 없는, 에게도, 있지, 않나요, 빛, 속도, 갈,...
# 41                                                 []
# 42  [슬픔, 위로, 하고, 감싸주는, 더, 큰, 슬픔, 힘, 오정희, 소설가, 증조, ...
# 43  [꿈, 현실, 사이, 방황, 하는, 대를, 위, 한, 청춘, 사용설명서, 꿈, 좇자...
# 44  [세상, 바꾼, 인물, 세상, 변화, 시킨, 책, 더, 설명, 필요, 없는, 세기,...
# 45  [시대, 가장, 논쟁, 적, 이고, 영향력, 있는, 지식인, 가지, 인생, 법칙, ...
# 46  [의약품, 기, 기분, 석, 학, 분권, 한, 후의, 첫, 번째, 개정, 분권, 후...
# 47  [한국, 최고, 마르크스, 경제학자, 김수행, 교수, 듣는, 자본론, 특강, 최고,...
# 48                                                 []
# 49  [세계, 적, 인, 석, 학, 저술, 한, 플랫폼, 비즈니스, 안내서, 포브스, 선...
#
#                                                   추천사
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [역시, 마이클, 샌델답다, 에는, 시대, 가장, 예민한, 이슈, 수술, 메스, 대...
# 5                                                  []
# 6   [서울역, 홈리스, 지내면서도, 안위, 보다는, 지갑, 잃어버린, 낯선, 부인, 안...
# 7   [부동산, 스터디, 우석, 신사임당, 이상한, 리뷰, 앨리스, 단, 희, 인, 플루...
# 8   [올해, 최고, 책, 록산, 게이, 작가, 세기, 견뎌내고, 번영, 이룬, 재일한국...
# 9                                                  []
# 10                                                 []
# 11  [올해, 최고, 책, 록산, 게이, 작가, 세기, 견뎌내고, 번영, 이룬, 재일한국...
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16  [간절히, 원, 해온, 은, 울, 고, 난, 뒤, 에야, 알, 게, 되는, 걸까, ...
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22  [내, 맘대로, 올해, 책, 물고기, 는, 존재, 하지, 않는다, 책장, 덮는, 순...
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27  [부동산, 스터디, 우석, 신사임당, 이상한, 리뷰, 앨리스, 단, 희, 인, 플루...
# 28                                                 []
# 29  [작가, 소재, 택하, 는, 아니라, 반, 대, 일지, 도, 모른다는, 생각, 한강...
# 30                                                 []
# 31                                                 []
# 32                                                 []
# 33                                                 []
# 34                                                 []
# 35  [한때, 좋은, 대학, 만, 가면, 앞길, 훤히, 열릴, 이라는, 믿음, 진실, 이...
# 36                                                 []
# 37                                                 []
# 38  [세기, 후반, 등장, 한, 디지털, 혁명, 인터넷, 혁명, 은, 모바일, 혁명, ...
# 39  [내, 맘대로, 올해, 책, 모자라지도, 하지도, 않은, 적당한, 온도, 따뜻함과,...
# 40  [김, 초엽, 눈부신, 데뷔, 이후, 줄곧, 두, 번째, 소설, 집, 기다려, 왔다...
# 41                                                 []
# 42  [태생, 지를, 빌려, 삼천이, 새, 비, 서로, 부르며, 한, 세상, 살, 냈던,...
# 43  [책, 추천사, 의뢰, 받으면서, 떠오른, 생각, 은, 였습니다, 청춘, 한, 줄기...
# 44                                                 []
# 45  [지금, 세상, 은, 조던, 피터슨, 필요, 한다, 더글러스, 머리, 유럽, 죽음,...
# 46                                                 []
# 47                                                 []
# 48                                                 []
# 49  [세기, 후반, 등장, 한, 디지털, 혁명, 인터넷, 혁명, 은, 모바일, 혁명, ...

# %%
df
# Out:
#     순위                                                도서명  \
# 0    1                             [지구, 한아, 뿐, 정세랑, 장편소설]
# 1    2               [돈, 속성, 최, 상위, 부자, 말, 하는, 돈, 대한, 모든]
# 2    3                                        [회계, 원리, 판]
# 3    4  [달러, 구트, 꿈, 백화점, 주문, 하신, 꿈, 은, 매진, 입니다, 이미, 장편소설]
# 4    5            [공정하다는, 착각, 능력, 주의, 는, 같은, 기회, 제공, 하는가]
# 5    6                     [달러, 구트, 꿈, 백화점, 단골, 손님, 찾습니다]
# 6    7                                         [불편한, 편의점]
# 7    8    [부의, 추월, 차선, 부자, 말, 해, 주지, 않는, 진정한, 부를, 얻는, 방법]
# 8    9                                              [파친코]
# 9   10                                      [미드나잇, 라이브러리]
# 10  11                                        [정의, 란, 인가]
# 11  12                                 [파친코, 이민, 진, 장편소설]
# 12  13                                      [칵테일, 러브, 좀비]
# 13  14                      [빛, 속도, 갈, 수, 없다면, 김, 초엽, 소설]
# 14  15                                        [중국, 말, 한다]
# 15  16                                      [글로벌, 경영, 제판]
# 16  17                                        [지구, 끝, 온실]
# 17  18                           [잃어버린, 역사, 회복, 위, 한, 시작]
# 18  19                                          [마케팅, 전략]
# 19  20                          [채식주의자, 한강, 연작, 소설, 장편소설]
# 20  21  [지적, 대화, 위, 한, 넓고, 얕은, 지식, 한, 권, 편안하게, 즐기는, 지식...
# 21  22                             [좋은, 음식, 올바른, 식사, 개정판]
# 22  23  [물고기, 는, 존재, 하지, 않는다, 상실, 사랑, 숨어, 있는, 삶, 질서, 관...
# 23  24                                 [아몬드, 손, 원평, 장편소설]
# 24  25                 [교육, 시설, 건축, 위, 한, 설계, 디테일, 도해, 집]
# 25  26                                       [음식, 세계, 문화]
# 26  27                    [예술, 환영, 회화, 적, 재현, 심리학, 적, 연구]
# 27  28    [부의, 추월, 차선, 부자, 말, 해, 주지, 않는, 진정한, 부를, 얻는, 방법]
# 28  29                                       [실행, 집중, 하라]
# 29  30                            [작별, 하지, 않는다, 한강, 장편소설]
# 30  31                [한번, 통과, 하는, 논문, 결과, 표, 작성, 해석, 방법]
# 31  32                                  [구의, 증명, 최진영, 소설]
# 32  33                                   [권, 마법사, 돌, 개정판]
# 33  34                           [이공, 계, 생, 위, 한, 확률, 통계]
# 34  35                             [완전한, 행복, 정, 유정, 장편소설]
# 35  36         [아들, 돈, 공부, 해야, 한다, 억, 부자, 아빠, 현실, 경제, 수업]
# 36  37                                       [총, 균, 쇠, 판]
# 37  38                                            [미래, 부]
# 38  39     [플랫폼, 레볼루션, 차, 산업혁명, 시대, 지배, 할, 플랫폼, 비즈니스, 모든]
# 39  40                             [어서, 오세요, 남동, 서점, 입니다]
# 40  41                        [방금, 떠나온, 세계, 김, 초엽, 소설, 집]
# 41  42                                      [심리학, 이란, 인가]
# 42  43                                 [밝은, 밤, 최은영, 장편소설]
# 43  44               [미래, 진로, 고민, 하는, 대가, 준비, 해야, 할, 개정판]
# 44  45                                            [침묵, 봄]
# 45  46                     [질서, 너머, 인생, 단계, 나아가는, 가지, 법칙]
# 46  47                            [의약품, 기, 기분, 석, 학, 개정판]
# 47  48                                          [자본론, 공부]
# 48  49                                   [일만, 합격, 하는, 엑셀]
# 49  50     [플랫폼, 레볼루션, 차, 산업혁명, 시대, 지배, 할, 플랫폼, 비즈니스, 모든]
#
#                        저자                  출판사  발행연도  대출횟수  \
# 0                   [정세랑]                 [난다]  2019    19
# 1                   [김승호]        [스노우, 폭스, 북스]  2020    19
# 2                   [김기동]               [샘앤북스]  2017    18
# 3                    [이미]            [팩토리, 나인]  2020    18
# 4                      []            [와이즈, 베리]  2020    17
# 5                    [이미]            [팩토리, 나인]  2021    16
# 6                   [김호연]          [나무, 옆, 의자]  2021    15
# 7                      []                 [토트]  2022    14
# 8                      []             [문학사, 상]  2018    13
# 9                      []        [인, 플루, 엔, 셜]  2021    13
# 10                     []                [김영사]  2010    12
# 11                     []             [문학사, 상]  2018    12
# 12                  [조예은]               [안전가옥]  2020    12
# 13                [김, 초엽]                 [허블]  2019    12
# 14           [양산, 췬, 외지음]    [신, 원, 문, 화사, 신원]  2008    12
# 15                   [이철]                 [학현]  2019    11
# 16                [김, 초엽]           [자이언트, 북스]  2021    11
# 17     [노목, 천연, 계, 탐, 사관]                [시조사]  2003    11
# 18                [박철, 주]                 [형설]  2016    11
# 19                   [한강]                 [창비]  2009    11
# 20                [채, 사장]             [한빛, 비즈]  2015    11
# 21                     []                [시조사]  2009    11
# 22                     []                  [곰]  2021    11
# 23                [손, 원평]                 [창비]  2017    10
# 24                     []            [엠지에이치북스]  2017    10
# 25           [김건희, 외, 지음]                [파워북]  2020    10
# 26                     []            [열, 화, 당]  2003     9
# 27                     []            [토트, 북새통]  2013     9
# 28                     []             [세기, 북스]  2004     9
# 29                   [한강]               [문학동네]  2021     9
# 30  [히든, 그레이스, 논문, 통계, 팀]           [한빛, 아카데미]  2018     9
# 31                  [최진영]               [은행나무]  2015     9
# 32                     []             [문학, 수첩]  2014     8
# 33                [안승, 철]  [한빛, 아카데미, 한빛, 미디어]  2014     8
# 34                [정, 유정]               [은행나무]  2021     8
# 35                [정선, 용]            [알에이치코리아]  2021     8
# 36                     []             [문학사, 상]  2018     8
# 37                     []             [세종, 서적]  2000     8
# 38                     []                 [부키]  2017     8
# 39                [황, 보름]           [클레이, 하우스]  2022     8
# 40                [김, 초엽]                [한겨레]  2021     8
# 41                     []             [스타, 북스]  2011     8
# 42                  [최은영]               [문학동네]  2021     8
# 43                  [김주형]          [미래, 문, 화사]  2021     8
# 44                     []            [에코, 리브르]  2011     8
# 45                     []        [웅진, 지식, 하우스]  2021     7
# 46   [약품, 분, 석, 학, 분, 과회]              [동, 명사]  2020     7
# 47                  [김수행]              [돌, 베개]  2014     7
# 48                  [김경희]  [한빛, 아카데미, 한빛, 미디어]  2017     7
# 49                     []                 [부키]  2017     7
#
#                                                  카테고리  \
# 0                             국내도서 소설시희곡 한국소설 한국 장편소설
# 1   국내도서 경제 경영 투자재테크 재테크일반 국내도서 미디어 추천 중앙일보 국내도서  ...
# 2               국내도서 수험서 자격증 경제금융회계물류 경제경영 기타자격증  관리사
# 3   국내도서 소설시희곡 장르소설 판타지 국내도서 소설시희곡 한국소설 한국 장편소설 국내...
# 4   국내도서 사회 정치 사회학 사회사사회문화 국내도서 인문 윤리학 국내도서 미디어 추천...
# 5   국내도서 소설시희곡 장르소설 판타지 국내도서 소설시희곡 한국소설 한국 장편소설 국내...
# 6   국내도서 소설시희곡 한국소설 한국 장편소설 국내도서  올해의 책 년 올해의 책 후보...
# 7                             국내도서 경제 경영 경제 경제상식경제이야기
# 8   국내도서 소설시희곡 영미소설 영미 장편소설 국내도서 미디어 추천 한겨레 국내도서  ...
# 9   국내도서 소설시희곡 영미소설 영미 장편소설 국내도서  올해의 책 년 올해의 책 후보...
# 10              국내도서 사회 정치 사회학 사회사상사 국내도서 인문 철학사상 관념론
# 11                            국내도서 소설시희곡 영미소설 영미 장편소설
# 12  국내도서 소설시희곡 장르소설 추리미스터리 국내도서 소설시희곡 장르소설 공포스릴러 국...
# 13  국내도서 소설시희곡 장르소설  국내도서 소설시희곡 한국소설 한국 단편소설 국내도서 ...
# 14                       국내도서 역사 동양사동양문화 중국역사문화 중국고대사
# 15                            국내도서 대학교재 경상계열 경영학 국제경영
# 16  국내도서 소설시희곡 장르소설  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 ...
# 17                              국내도서 역사 한국사한국문화 한국사일반
# 18                               국내도서 대학교재 경상계열 광고마케팅
# 19     국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 해외문학상 수상작 부커상 수상작
# 20                            국내도서 인문 인문교양 교양으로 읽는 인문
# 21                               국내도서 건강 취미 건강에세이건강기타
# 22  국내도서 자연과학 생명과학 생물학 국내도서 자연과학 생명과학 유전자진화바이러스 국내...
# 23  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 행복한아침독서책둥이 추천  년 ...
# 24                               국내도서 예술 건축 건축이론비평건축사
# 25                       국내도서 대학교재 예체능문화기타 계열 식품영양학조리
# 26                         국내도서 대학교재 대학출판부 이화여자대학교출판부
# 27                            국내도서 경제 경영 경제 경제상식경제이야기
# 28  국내도서 경제 경영 경영 경영일반 국내도서  올해의 책 년 올해의 책 후보도서 국내...
# 29  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 국내문학상 수상작 대산문학상 수...
# 30                                   국내도서 대학교재 인문학 계열
# 31                            국내도서 소설시희곡 한국소설 한국 단편소설
# 32  국내도서 소설시희곡 장르소설 판타지 국내도서 소설시희곡 테마소설 영화와 드라마 원작...
# 33            국내도서 대학교재 자연과학 계열 수학 국내도서 자연과학 수학 확률통계학
# 34  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 미디어 추천 한겨레 국내도서  ...
# 35      국내도서 경제 경영 경제 국제경제금융화폐 국내도서 경제 경영 투자재테크 재테크일반
# 36  국내도서 사회 정치 사회비평비판 국제사회비평 국내도서 사회 정치 사회학 사회사사회문...
# 37   국내도서 경제 경영 투자재테크 재테크일반 국내도서  올해의 책 년 올해의 책 후보도서
# 38  국내도서 경제 경영 경제 각국 경제경제사전망 경제전망 국내도서 세종도서구문화체육관광...
# 39                            국내도서 소설시희곡 한국소설 한국 장편소설
# 40  국내도서 소설시희곡 한국소설 한국 단편소설 국내도서 미디어 추천 한겨레 국내도서  ...
# 41  국내도서 인문 심리 주제로 읽는 심리학 쉽게 읽는 심리학 국내도서 인문 심리 주제로...
# 42  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 국내문학상 수상작 대산문학상 수...
# 43                                  국내도서 자기계발 성공학경력관리
# 44  국내도서 사회 정치 사회학 사회학일반 국내도서 사회 정치 생태환경 환경문제 국내도서...
# 45  국내도서 인문 심리 심리학 이론 국내도서 미디어 추천 조선일보 국내도서  올해의 책...
# 46                        국내도서 대학교재 의약학간호 계열 의학 기타 교재
# 47  국내도서 사회 정치 사회비평비판 노동문제 국내도서 사회 정치 정치외교 서양정치사상정...
# 48                               국내도서  모바일 오피스 활용  엑셀
# 49  국내도서 경제 경영 경제 각국 경제경제사전망 경제전망 국내도서 세종도서구문화체육관광...
#
#                                                  저자소개  \
# 0   [서울, 태어났다, 판타스틱, 드림, 드림, 드림, 발표, 하며, 작품, 활동, 시...
# 1   [한인, 기업, 최초, 글로벌, 외식, 그룹, 인, 회장, 이다, 한국, 전, 세계...
# 2   [고려대학교, 경영학, 고려대학교, 대학원, 경영학, 과를, 졸업, 회계학, 전공,...
# 3   [부산, 태어났다, 부산, 대, 재료공학, 공부, 하고, 반도체, 엔지니어, 했다,...
# 4   [이후, 한국, 정의, 열풍, 불러일으켰다, 세, 최연, 소, 하버드, 대학교, 교...
# 5   [부산, 태어났다, 부산, 대, 재료공학, 공부, 하고, 반도체, 엔지니어, 했다,...
# 6   [화만, 화, 소설, 넘나, 들며, 온갖, 이야기, 써, 나가는, 전, 천후, 스토...
# 7   [투자자, 이자, 자수, 성가, 한, 백만장자, 개, 국어, 넘는, 언어, 출, 간...
# 8   [전, 세계, 뜨거운, 관심, 사랑, 받고, 있는, 한국, 계, 미국인, 소설가, ...
# 9   [영국, 요크셔, 출신, 동화작가, 겸, 소설가, 다, 출, 간, 한, 첫, 소설,...
# 10  [이후, 한국, 정의, 열풍, 불러일으켰다, 세, 최연, 소, 하버드, 대학교, 교...
# 11  [전, 세계, 뜨거운, 관심, 사랑, 받고, 있는, 한국, 계, 미국인, 소설가, ...
# 12  [회, 황금가지, 타임, 리프, 공모전, 오버, 랩, 나이프, 나이프, 우수상, 회...
# 13  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 14  [상해, 사회과학, 원, 역사, 연구소, 연구원, 상해시, 중학교, 교사, 길림, ...
# 15                                                 []
# 16  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 17                                                 []
# 18  [일본, 게이오, 대학, 상학, 연, 마케팅, 연구, 하였고, 소, 비시, 장, 에...
# 19  [늦은, 태어났다, 연세대, 국문과, 졸업, 한, 뒤, 문학과사회, 시를, 발표, ...
# 20  [겨울, 출, 간, 한, 첫, 책, 지적, 대화, 위, 한, 넓고, 얕은, 지식, ...
# 21                                                 []
# 22  [방송, 계, 퓰리처상, 불리는, 피버디상, 수상한, 과학, 전, 문, 기자, 넘게...
# 23  [서울, 태어났다, 서강대, 학교, 사회학, 철학, 공부, 했고, 한국, 영화아카데...
# 24                                                 []
# 25                                                 []
# 26  [곰, 브리, 치는, 오스트리아, 빈, 태어났다, 미술사, 박사학위, 취득, 하였고...
# 27  [투자자, 이자, 자수, 성가, 한, 백만장자, 개, 국어, 넘는, 언어, 출, 간...
# 28  [래, 리, 보시, 디, 는, 포춘, 선정, 한, 기술, 제조업, 계, 리더, 인,...
# 29  [늦은, 태어났다, 연세대, 국문과, 졸업, 한, 뒤, 문학과사회, 시를, 발표, ...
# 30  [김성은, 주, 히든, 그레이스, 대표, 현재, 데이터, 분석, 머신, 러닝, 프로...
# 31  [눈, 많이, 내리던, 날, 서울, 태어났다, 낮, 엔, 하고, 밤, 엔, 글, 쓰...
# 32  [새로운, 판매, 기록, 세우고, 수많은, 상, 수상한, 해리, 포터, 시리즈, 작...
# 33  [성균관대, 학교, 수학과, 학사, 석사, 박사, 통계학, 전공, 학위, 취득, 하...
# 34  [소설가, 전남, 함평, 출생, 이다, 대학, 시절, 에는, 국문과, 친구, 소설,...
# 35  [간, 유통업, 계, 종사, 하며, 대기업, 직장인, 살았다, 휴일, 근무, 며, ...
# 36  [미국, 보스턴, 출생, 했다, 록스버리, 라틴, 스쿨, 하버드, 대학교, 졸업, ...
# 37  [글, 쓰기, 시작, 했다, 교육, 자기계발, 인문학, 다양한, 분야, 서른, 권,...
# 38  [보스턴, 대학, 교수, 이며, 매사추세츠, 공과대학, 디지털, 경제, 이니셔티브,...
# 39  [대학, 컴퓨터공학, 전공, 하고, 소프트웨어, 개발자, 했다, 번의, 입사, 퇴사...
# 40  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 41                                                 []
# 42  [삼색, 고양이, 날, 태어나, 삼색, 고양이, 고등어, 고양이, 사는, 소설가, ...
# 43  [고등학교, 시절, 수능, 공부, 하는, 대신, 영어, 공부, 하여, 토익, 성적,...
# 44  [생태학, 시대, 어머니, 이자, 환경, 중요성, 깨워, 준, 레이첼, 카슨, 은,...
# 45  [토론토, 대학교, 심리학, 교수, 임상심리학, 가지, 인생, 법칙, 일약, 베스트...
# 46                                                 []
# 47  [일본, 태어나, 해방, 귀국, 해서, 고등학교, 대구, 살았다, 서울대학교, 상과...
# 48  [현재, 한남, 대학교, 국제, 교육, 센터, 교수, 재직, 중이, 며, 대전, 지...
# 49  [보스턴, 대학, 교수, 이며, 매사추세츠, 공과대학, 디지털, 경제, 이니셔티브,...
#
#                                                   책소개  \
# 0   [창비, 장편소설, 상, 한국, 일보, 문학상, 수상, 작가, 정세랑, 두번째, 장...
# 1   [연속, 최, 장기, 베스트셀러, 만, 깨어있는, 독자, 선택, 한, 경제, 경영,...
# 2   [회계, 원리, 는, 모든, 회계, 기초, 입니다, 본, 서는, 회계, 관, 한, ...
# 3   [여기는, 잠들어야만, 입장, 할, 수, 있는, 달러, 구트, 꿈, 백화점, 입니다...
# 4   [마이클, 샌델, 만의, 신간, 공정하다는, 착각, 출, 간, 샌델, 기울어진, 사...
# 5   [만, 독자, 사로잡은, 달러, 구트, 꿈, 백화점, 두, 번째, 이야기, 어느덧,...
# 6   [최고, 재미, 감동, 선사, 하는, 힐링, 소설, 원조, 주요, 서점, 종합, 베...
# 7   [미국, 아마존, 금융, 사업, 분야, 위, 국내, 유명, 서점, 간, 종합, 베스...
# 8   [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 9   [밤, 시, 죽기, 전, 에만, 열리는, 마법, 도서관, 인생, 두, 번째, 기회,...
# 10  [한국, 정의, 열풍, 불러일으킨, 마이클, 샌델, 은, 구제, 금융, 대리, 출산...
# 11  [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 12  [안전가옥, 쇼트, 시리즈, 두, 번째, 책, 조예은, 작가, 단, 편집, 이다, ...
# 13  [우아한, 계보, 후지, 난, 겨울, 바이오, 센서, 만드는, 과학, 도, 였던, ...
# 14  [총, 권, 구성, 되어, 있으며, 원시, 사회, 에서부터, 청나라, 멸망, 중국,...
# 15  [책, 은, 국제, 경영, 관, 한, 이론, 서, 입니다, 국제, 경영, 기초, 적...
# 16  [김, 초엽, 첫, 장편소설, 간절히, 기다려, 온, 이야기, 이미, 폭넓은, 독자...
# 17                                                 []
# 18  [마케팅, 전략, 은, 커, 교수, 맥러, 그린, 교수, 공저, 한, 번역, 한, ...
# 19  [인터내셔널, 부커상, 산클레멘테, 문학상, 수상작, 전세계, 주목, 한, 한강, ...
# 20  [지적, 대화, 하기, 위해, 서, 깔려, 있어야, 하는, 가장, 기본, 지식, 시...
# 21  [현대인, 위, 한, 건강, 생활, 가이드, 시리즈, 좋은, 음식, 올바른, 식사,...
# 22  [방송, 계, 퓰리처상, 피버디상, 수상자, 룰루, 밀러, 사랑, 혼돈, 과학, 적...
# 23  [공감, 불능, 사회, 차가, 움, 녹이는, 아몬드, 매혹, 적, 인, 문체, 독특...
# 24                                                 []
# 25  [세계, 각국, 음식, 문화, 대한, 연구, 는, 인간, 의식, 구조, 삶, 방식,...
# 26  [번역본, 현대, 시, 지각, 이론, 입, 각하, 회화, 적, 재현, 역사, 심리,...
# 27  [미국, 아마존, 금융, 사업, 분야, 위, 국내, 유명, 서점, 간, 종합, 베스...
# 28  [똑같이, 우수한, 비, 전과, 전략, 수립, 하였음에도, 불구, 하고, 기업, 은...
# 29  [생각, 하면, 견딜, 수, 있나, 가슴, 활활, 일어나는, 불, 없다면, 기어이,...
# 30  [분석, 방법, 결과, 표, 작성, 해석, 방법, 논문, 초심자, 해야, 할, 하지...
# 31  [먼저, 죽는다면나는, 먹을, 거, 래야, 없이도, 죽지, 않고, 살, 수, 있어,...
# 32  [해리, 포터, 세대, 해리, 포터, 세대, 위, 한, 해리, 포터, 세대, 의한,...
# 33  [빅데이터, 시대, 이제, 는, 통계, 적, 사고, 경쟁력, 이다, 는, 살아가면서...
# 34  [다시, 정, 유정, 자기애, 늪, 빠진, 삶은, 위태, 로운, 압도, 적, 서사,...
# 35  [베스트셀러, 아들, 돈, 공부, 해야, 한다, 만, 부, 기념, 골드, 에디, 션...
# 36  [민족, 은, 민족, 정복, 지배, 대상, 전락, 하고, 말았는가, 원주민, 은, ...
# 37  [석유, 는, 데이터, 부동산, 은, 데이터, 센터, 코로나, 가속, 화, 한, 차...
# 38  [차, 산업혁명, 주인공, 은, 플랫폼, 축하, 거나, 활용, 하는, 자가, 될, ...
# 39  [받아들여지고, 있다는, 느낌, 이렇게, 슬프고도, 좋을, 줄, 이야, 브런치, 북...
# 40  [사랑, 입자, 타고, 낯선, 세계, 떠, 도, 는, 경이, 롭고, 아름다운, 우주...
# 41  [옥스퍼드, 대학, 입문, 총서, 시리즈, 심리학, 개론, 서, 두뇌, 대한, 과학...
# 42  [백, 감싸안으며, 이어지는, 사랑, 숨, 기록, 쇼코, 미소, 내게, 무, 해한,...
# 43  [현실, 타협, 하는, 삶, 에서도, 행복, 만드는, 방법, 꿈꾸기에는, 불안하고,...
# 44  [세기, 가장, 큰, 영향력, 미친, 책, 컬, 지는, 침묵, 봄, 개정판, 이다,...
# 45  [피터슨, 돌아왔다, 전, 세계, 젊은이, 열광, 시킨, 인생, 법칙, 완결, 판,...
# 46  [분광분석, 분리, 분석, 첫, 단계, 로서, 기, 기분, 석, 학, 약학, 교육,...
# 47  [한국, 최고, 마르크스, 경제학자, 김수행, 교수, 듣는, 자본론, 특강, 자본론...
# 48  [버전, 담은, 첫, 교재, 강의, 경력, 깊고, 풍부한, 전문, 강, 사진, 시험...
# 49  [차, 산업혁명, 주인공, 은, 플랫폼, 축하, 거나, 활용, 하는, 자가, 될, ...
#
#                                                    목차  \
# 0                                  [지구, 한아, 뿐, 작가, 말]
# 1   [쇄, 기념, 개정, 증보, 판, 내면, 서, 프롤로그, 돈, 은, 인격, 체다, ...
# 2   [장, 회계, 기초, 이론, 절, 회계, 기초, 회, 계란, 인가, 회계, 정보, ...
# 3   [작가, 말, 프롤로그, 번째, 제자, 유서, 깊은, 가게, 주문, 하신, 꿈, 은...
# 4   [서론, 대학, 입시, 능력, 주의, 입시, 윤리, 능력, 지표, 따내기, 승자, ...
# 5   [프롤로그, 달러, 구트, 다락방, 장, 페니, 첫, 번째, 연봉, 협상, 장, 민...
# 6   [산, 해, 진미, 도시락, 제이, 에스, 오브, 제이, 에스, 삼각김밥, 용도, ...
# 7   [머리말, 람보르기니, 예언, 실현, 되다, 프롤로그, 부자, 되는, 길, 에는, ...
# 8                                                  []
# 9                                                  []
# 10  [책, 쏟아진, 찬사, 한국어, 판, 서, 문장, 정의, 란, 옳고, 그름, 판단,...
# 11                                                 []
# 12  [초대, 습지, 사랑, 칵테일, 러브, 좀비, 오버, 랩, 나이프, 나이프, 작품,...
# 13  [순례, 은, 돌아오지, 않는가, 스펙트럼, 공생, 가설, 빛, 속도, 갈, 수, ...
# 14  [발간, 즈음, 하여, 발, 간사, 꿈, 추구, 독자, 위해, 엮, 은, 중국, 역...
# 15  [글로벌화, 글로벌, 경영, 글로벌화, 글로벌, 경영, 이해, 글로벌, 화란, 인가...
# 16  [프롤로그, 장, 모스, 바나, 장, 프림, 빌리지, 장, 지구, 끝, 온실, 작가...
# 17  [프롤로그, 일제시대, 종교, 정책, 보천교, 보천교, 민족, 독립운동, 식, 민권...
# 18  [장, 마케팅, 이란, 인가, 절, 마케팅, 이란, 절, 마케팅, 탄생, 의미, 절...
# 19  [채식주의자, 몽고반점, 나무, 불꽃, 새로, 쓴, 작가, 말, 작가, 말, 수록,...
# 20  [프롤로그, 책, 읽는, 방법, 준비, 운동, 세계, 구조, 화, 판단, 중, 지,...
# 21  [개혁, 필요한, 이유, 식생활, 영성, 건강, 개혁, 셋째, 천사, 기별, 합당,...
# 22  [프롤로그, 별, 머리, 담근, 소년, 섬, 선지자, 신, 없는, 막간, 극, 꼬리...
# 23                                                 []
# 24  [교육, 시설, 건축, 위, 한, 설계, 이론, 유형, 학습, 생활, 위, 한, 공...
# 25  [식생활, 문화, 이해, 하기, 음식, 문화, 역사, 선사시대, 음식, 문화, 역사...
# 26  [서문, 서론, 심리학, 양식, 수수께끼, 부, 유사성, 한계, 빛, 으로부터, 물...
# 27  [머리말, 람보르기니, 예언, 실현, 되다, 프롤로그, 부자, 되는, 길, 에는, ...
# 28  [부, 실행, 력, 인가, 장, 실행, 력, 없는, 비전은, 비극, 이다, 경영, ...
# 29  [부, 새, 결정, 실, 폭설, 새, 남은, 빛, 나무, 부, 밤, 작별, 하지, ...
# 30  [논문, 통계, 분석, 기초, 편, 사용, 할까, 요, 누가, 활용, 하면, 좋을까...
# 31                                    [구의, 증명, 작가, 말]
# 32                                                 []
# 33  [기술통계학, 자료, 정리, 요약, 도표, 이용, 한, 자료, 정리, 그림, 이용,...
# 34  [부, 그녀, 오리, 장, 장, 장, 부, 그녀, 는, 일까, 장, 장, 장, 부,...
# 35  [책, 쏟아진, 찬사, 만, 부, 기념, 골드, 에디, 션, 서문, 지금, 는, 다...
# 36  [친애하는, 한국, 독자, 드리는, 편지, 제레드, 다이아몬드, 증보, 판, 부쳐,...
# 37  [프롤로그, 는, 은, 는, 준비, 해야, 하는가, 새로운, 부가, 오고, 인공, ...
# 38  [한국어, 판, 서문, 우려, 스러운, 한국, 플랫폼, 경쟁력, 머리말, 플랫폼, ...
# 39  [서점, 은, 모습, 이어야, 할까, 이제, 더, 는, 울, 지, 않아도, 된다오,...
# 40  [최후, 라이, 오니, 마리, 춤, 로라, 숨, 그림자, 오래된, 협약, 인지, 공...
# 41  [심리학, 이란, 인가, 공부, 할, 인가, 두뇌, 속, 들어오게, 되는가, 인지,...
# 42                             [부, 부, 부, 부, 부, 작가, 말]
# 43  [추천사, 청춘, 한, 줄기, 빛, 될, 수, 있다면, 청춘, 머뭇거리, 기, 에는...
# 44  [감사, 글, 서문, 린다, 리, 내일, 위, 한, 우화, 참아야, 하는, 의무, ...
# 45  [법칙, 기존, 제도, 창의, 적, 변화, 함부로, 깎아내리지, 마라, 법칙, 내,...
# 46  [장, 분광분석법, 장, 분리, 분석, 법, 장, 전기화학, 분석, 법, 장, 원료...
# 47  [자본론, 대하, 자본주의, 사회, 는, 사라지지, 않을까, 인류, 경제, 사회, ...
# 48  [머리말, 시험, 소개, 시험, 인터페이스, 안내, 책, 학습, 방법, 목차, 화면...
# 49  [한국어, 판, 서문, 우려, 스러운, 한국, 플랫폼, 경쟁력, 머리말, 플랫폼, ...
#
#                                                 출판사서평  \
# 0   [점점, 줄어드는, 페이지, 보며, 아쉬워, 무거워진, 눈꺼풀, 참으며, 책, 읽는...
# 1   [는, 정말, 필요한, 나누려는, 사람, 이다, 최근, 사이, 수만, 명의, 사람,...
# 2   [회계, 원리, 회계, 원리, 는, 모든, 회계, 기초, 입니다, 본, 서는, 회계...
# 3   [텀블벅, 펀딩, 달성, 출, 간, 주, 연속, 종합, 베스트셀러, 위, 독자, 별...
# 4   [능력, 주의, 는, 공정하게, 작동, 하는가, 공정함, 정의, 란, 공식, 은, ...
# 5   [내내, 베스트셀러, 위, 독자, 뽑은, 최고, 힐링, 판타지, 잠들어야만, 입장,...
# 6   [원, 플러스, 원, 기쁨, 삼각김밥, 모양, 슬픔, 만, 원, 번의, 폭소, 터지...
# 7   [부자, 되기, 플랜, 속지, 마라, 지금, 까지의, 부자, 되기, 책, 이야기, ...
# 8   [회복, 연민, 대한, 강력한, 이야기, 버락, 오바마, 미국, 전, 대통령, 전,...
# 9   [영국, 아마존, 종합, 베스트셀러, 위, 미국, 아마존, 뉴욕타임스, 선데이타임스...
# 10  [정의, 둘러싼, 위대한, 철학자, 과의, 대화, 글로벌, 금융, 위기, 이후, 억...
# 11  [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 12  [토록, 생생한, 어둠, 감정, 은, 곧잘, 무시, 당한다, 여성, 이라서, 자식,...
# 13  [젊은, 소설가, 첫, 작품집, 이라고는, 믿기지, 않을, 정도, 매끄럽게, 이어지...
# 14  [일반, 독자, 위, 한, 중국, 역사, 문화, 집대성, 한, 백과사전, 중국, 저...
# 15                                                 []
# 16  [악마, 식물, 내, 정원, 자라고, 있는데, 거, 멸망, 징조, 아니야, 덩굴식물...
# 17                                                 []
# 18                                                 []
# 19  [폭력, 아름다, 움, 처절한, 공존, 새롭게, 읽히는, 한강, 소설, 힘년, 창비...
# 20  [만, 부, 밀리언셀러, 지대, 넓, 얕, 최초, 개정, 증보, 판, 지적, 대화,...
# 21                                                 []
# 22  [워싱턴포스트, 북, 라이엇, 내서, 널퍼, 블릭, 라디오, 시카고, 트리뷴, 스미...
# 23  [감정, 느끼지, 못, 하는, 소년, 특별한, 성장, 아몬드, 주인공, 윤재, 는,...
# 24                                                 []
# 25  [식생활, 이란, 인간, 생활, 중, 생명, 유지, 생체, 활동, 필요한, 영양분,...
# 26  [심리학, 철학, 문, 화사, 전반, 가로지르는, 곰, 브리, 치, 미술사, 연구,...
# 27  [부자, 되기, 플랜, 속지, 마라, 지금, 까지의, 부자, 되기, 책, 이야기, ...
# 28                                                 []
# 29  [이상하지, 눈, 은, 하늘, 저런, 게, 내려오지, 작별, 지, 않는다는, 소설가...
# 30  [논문, 통계, 분석, 기초, 편, 에서는, 통계, 분석, 하기, 전, 알아야, 하...
# 31  [상상, 가능, 케, 하는, 사랑, 그런, 사랑, 가능, 케, 하는, 상상, 여자,...
# 32  [해리, 포터, 키즈, 완벽하게, 구현, 한, 롤링, 마법, 세계, 시대, 가장, ...
# 33                                                 []
# 34  [행복, 은, 덧셈, 아니야, 행복, 은, 뺄셈, 이야, 완전해질, 불행, 가능성,...
# 35  [경제, 는, 사람, 사이, 실생활, 밀착, 형, 경제, 수업, 아들, 돈, 공부,...
# 36  [인류, 문명, 수수께끼, 새로운, 풀어, 낸, 명, 개정, 신판, 특별, 증보, ...
# 37  [석유, 는, 데이터, 부동산, 은, 데이터, 센터, 코로나, 가속, 화, 한, 차...
# 38  [세계, 적, 인, 석, 학, 저술, 한, 플랫폼, 비즈니스, 안내서, 포브스, 선...
# 39  [먼저, 읽은, 독자, 요청, 종이, 책, 다시, 태어난, 소설, 출, 간, 전자책...
# 40  [사랑, 끝내, 이해, 할, 수, 없는, 에게도, 있지, 않나요, 빛, 속도, 갈,...
# 41                                                 []
# 42  [슬픔, 위로, 하고, 감싸주는, 더, 큰, 슬픔, 힘, 오정희, 소설가, 증조, ...
# 43  [꿈, 현실, 사이, 방황, 하는, 대를, 위, 한, 청춘, 사용설명서, 꿈, 좇자...
# 44  [세상, 바꾼, 인물, 세상, 변화, 시킨, 책, 더, 설명, 필요, 없는, 세기,...
# 45  [시대, 가장, 논쟁, 적, 이고, 영향력, 있는, 지식인, 가지, 인생, 법칙, ...
# 46  [의약품, 기, 기분, 석, 학, 분권, 한, 후의, 첫, 번째, 개정, 분권, 후...
# 47  [한국, 최고, 마르크스, 경제학자, 김수행, 교수, 듣는, 자본론, 특강, 최고,...
# 48                                                 []
# 49  [세계, 적, 인, 석, 학, 저술, 한, 플랫폼, 비즈니스, 안내서, 포브스, 선...
#
#                                                   추천사
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [역시, 마이클, 샌델답다, 에는, 시대, 가장, 예민한, 이슈, 수술, 메스, 대...
# 5                                                  []
# 6   [서울역, 홈리스, 지내면서도, 안위, 보다는, 지갑, 잃어버린, 낯선, 부인, 안...
# 7   [부동산, 스터디, 우석, 신사임당, 이상한, 리뷰, 앨리스, 단, 희, 인, 플루...
# 8   [올해, 최고, 책, 록산, 게이, 작가, 세기, 견뎌내고, 번영, 이룬, 재일한국...
# 9                                                  []
# 10                                                 []
# 11  [올해, 최고, 책, 록산, 게이, 작가, 세기, 견뎌내고, 번영, 이룬, 재일한국...
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16  [간절히, 원, 해온, 은, 울, 고, 난, 뒤, 에야, 알, 게, 되는, 걸까, ...
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22  [내, 맘대로, 올해, 책, 물고기, 는, 존재, 하지, 않는다, 책장, 덮는, 순...
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27  [부동산, 스터디, 우석, 신사임당, 이상한, 리뷰, 앨리스, 단, 희, 인, 플루...
# 28                                                 []
# 29  [작가, 소재, 택하, 는, 아니라, 반, 대, 일지, 도, 모른다는, 생각, 한강...
# 30                                                 []
# 31                                                 []
# 32                                                 []
# 33                                                 []
# 34                                                 []
# 35  [한때, 좋은, 대학, 만, 가면, 앞길, 훤히, 열릴, 이라는, 믿음, 진실, 이...
# 36                                                 []
# 37                                                 []
# 38  [세기, 후반, 등장, 한, 디지털, 혁명, 인터넷, 혁명, 은, 모바일, 혁명, ...
# 39  [내, 맘대로, 올해, 책, 모자라지도, 하지도, 않은, 적당한, 온도, 따뜻함과,...
# 40  [김, 초엽, 눈부신, 데뷔, 이후, 줄곧, 두, 번째, 소설, 집, 기다려, 왔다...
# 41                                                 []
# 42  [태생, 지를, 빌려, 삼천이, 새, 비, 서로, 부르며, 한, 세상, 살, 냈던,...
# 43  [책, 추천사, 의뢰, 받으면서, 떠오른, 생각, 은, 였습니다, 청춘, 한, 줄기...
# 44                                                 []
# 45  [지금, 세상, 은, 조던, 피터슨, 필요, 한다, 더글러스, 머리, 유럽, 죽음,...
# 46                                                 []
# 47                                                 []
# 48                                                 []
# 49  [세기, 후반, 등장, 한, 디지털, 혁명, 인터넷, 혁명, 은, 모바일, 혁명, ...

# %% [markdown]
# # 8 단어 정규화

# %%
from konlpy.tag import Komoran

# %%
def normalize_text(text):
    komoran = Komoran()
    tokens = komoran.morphs(text)
    normalized_tokens = [komoran.normalize(token) for token in tokens]
    normalized_text = ' '.join(normalized_tokens)
    return normalized_text

# %%
# 정규화할 열 목록
columns_to_normalize = ['저자소개', '책소개', '출판사서평', '추천사']

# %%
# 각 열에 대한 정규화 적용
for column in columns_to_normalize:
    df[column] = df[column].apply(lambda x: normalize_text(x) if isinstance(x, str) else x)

# %% [markdown]
# # 최종

# %%
df
# Out:
#     순위                                                도서명  \
# 0    1                             [지구, 한아, 뿐, 정세랑, 장편소설]
# 1    2               [돈, 속성, 최, 상위, 부자, 말, 하는, 돈, 대한, 모든]
# 2    3                                        [회계, 원리, 판]
# 3    4  [달러, 구트, 꿈, 백화점, 주문, 하신, 꿈, 은, 매진, 입니다, 이미, 장편소설]
# 4    5            [공정하다는, 착각, 능력, 주의, 는, 같은, 기회, 제공, 하는가]
# 5    6                     [달러, 구트, 꿈, 백화점, 단골, 손님, 찾습니다]
# 6    7                                         [불편한, 편의점]
# 7    8    [부의, 추월, 차선, 부자, 말, 해, 주지, 않는, 진정한, 부를, 얻는, 방법]
# 8    9                                              [파친코]
# 9   10                                      [미드나잇, 라이브러리]
# 10  11                                        [정의, 란, 인가]
# 11  12                                 [파친코, 이민, 진, 장편소설]
# 12  13                                      [칵테일, 러브, 좀비]
# 13  14                      [빛, 속도, 갈, 수, 없다면, 김, 초엽, 소설]
# 14  15                                        [중국, 말, 한다]
# 15  16                                      [글로벌, 경영, 제판]
# 16  17                                        [지구, 끝, 온실]
# 17  18                           [잃어버린, 역사, 회복, 위, 한, 시작]
# 18  19                                          [마케팅, 전략]
# 19  20                          [채식주의자, 한강, 연작, 소설, 장편소설]
# 20  21  [지적, 대화, 위, 한, 넓고, 얕은, 지식, 한, 권, 편안하게, 즐기는, 지식...
# 21  22                             [좋은, 음식, 올바른, 식사, 개정판]
# 22  23  [물고기, 는, 존재, 하지, 않는다, 상실, 사랑, 숨어, 있는, 삶, 질서, 관...
# 23  24                                 [아몬드, 손, 원평, 장편소설]
# 24  25                 [교육, 시설, 건축, 위, 한, 설계, 디테일, 도해, 집]
# 25  26                                       [음식, 세계, 문화]
# 26  27                    [예술, 환영, 회화, 적, 재현, 심리학, 적, 연구]
# 27  28    [부의, 추월, 차선, 부자, 말, 해, 주지, 않는, 진정한, 부를, 얻는, 방법]
# 28  29                                       [실행, 집중, 하라]
# 29  30                            [작별, 하지, 않는다, 한강, 장편소설]
# 30  31                [한번, 통과, 하는, 논문, 결과, 표, 작성, 해석, 방법]
# 31  32                                  [구의, 증명, 최진영, 소설]
# 32  33                                   [권, 마법사, 돌, 개정판]
# 33  34                           [이공, 계, 생, 위, 한, 확률, 통계]
# 34  35                             [완전한, 행복, 정, 유정, 장편소설]
# 35  36         [아들, 돈, 공부, 해야, 한다, 억, 부자, 아빠, 현실, 경제, 수업]
# 36  37                                       [총, 균, 쇠, 판]
# 37  38                                            [미래, 부]
# 38  39     [플랫폼, 레볼루션, 차, 산업혁명, 시대, 지배, 할, 플랫폼, 비즈니스, 모든]
# 39  40                             [어서, 오세요, 남동, 서점, 입니다]
# 40  41                        [방금, 떠나온, 세계, 김, 초엽, 소설, 집]
# 41  42                                      [심리학, 이란, 인가]
# 42  43                                 [밝은, 밤, 최은영, 장편소설]
# 43  44               [미래, 진로, 고민, 하는, 대가, 준비, 해야, 할, 개정판]
# 44  45                                            [침묵, 봄]
# 45  46                     [질서, 너머, 인생, 단계, 나아가는, 가지, 법칙]
# 46  47                            [의약품, 기, 기분, 석, 학, 개정판]
# 47  48                                          [자본론, 공부]
# 48  49                                   [일만, 합격, 하는, 엑셀]
# 49  50     [플랫폼, 레볼루션, 차, 산업혁명, 시대, 지배, 할, 플랫폼, 비즈니스, 모든]
#
#                        저자                  출판사  발행연도  대출횟수  \
# 0                   [정세랑]                 [난다]  2019    19
# 1                   [김승호]        [스노우, 폭스, 북스]  2020    19
# 2                   [김기동]               [샘앤북스]  2017    18
# 3                    [이미]            [팩토리, 나인]  2020    18
# 4                      []            [와이즈, 베리]  2020    17
# 5                    [이미]            [팩토리, 나인]  2021    16
# 6                   [김호연]          [나무, 옆, 의자]  2021    15
# 7                      []                 [토트]  2022    14
# 8                      []             [문학사, 상]  2018    13
# 9                      []        [인, 플루, 엔, 셜]  2021    13
# 10                     []                [김영사]  2010    12
# 11                     []             [문학사, 상]  2018    12
# 12                  [조예은]               [안전가옥]  2020    12
# 13                [김, 초엽]                 [허블]  2019    12
# 14           [양산, 췬, 외지음]    [신, 원, 문, 화사, 신원]  2008    12
# 15                   [이철]                 [학현]  2019    11
# 16                [김, 초엽]           [자이언트, 북스]  2021    11
# 17     [노목, 천연, 계, 탐, 사관]                [시조사]  2003    11
# 18                [박철, 주]                 [형설]  2016    11
# 19                   [한강]                 [창비]  2009    11
# 20                [채, 사장]             [한빛, 비즈]  2015    11
# 21                     []                [시조사]  2009    11
# 22                     []                  [곰]  2021    11
# 23                [손, 원평]                 [창비]  2017    10
# 24                     []            [엠지에이치북스]  2017    10
# 25           [김건희, 외, 지음]                [파워북]  2020    10
# 26                     []            [열, 화, 당]  2003     9
# 27                     []            [토트, 북새통]  2013     9
# 28                     []             [세기, 북스]  2004     9
# 29                   [한강]               [문학동네]  2021     9
# 30  [히든, 그레이스, 논문, 통계, 팀]           [한빛, 아카데미]  2018     9
# 31                  [최진영]               [은행나무]  2015     9
# 32                     []             [문학, 수첩]  2014     8
# 33                [안승, 철]  [한빛, 아카데미, 한빛, 미디어]  2014     8
# 34                [정, 유정]               [은행나무]  2021     8
# 35                [정선, 용]            [알에이치코리아]  2021     8
# 36                     []             [문학사, 상]  2018     8
# 37                     []             [세종, 서적]  2000     8
# 38                     []                 [부키]  2017     8
# 39                [황, 보름]           [클레이, 하우스]  2022     8
# 40                [김, 초엽]                [한겨레]  2021     8
# 41                     []             [스타, 북스]  2011     8
# 42                  [최은영]               [문학동네]  2021     8
# 43                  [김주형]          [미래, 문, 화사]  2021     8
# 44                     []            [에코, 리브르]  2011     8
# 45                     []        [웅진, 지식, 하우스]  2021     7
# 46   [약품, 분, 석, 학, 분, 과회]              [동, 명사]  2020     7
# 47                  [김수행]              [돌, 베개]  2014     7
# 48                  [김경희]  [한빛, 아카데미, 한빛, 미디어]  2017     7
# 49                     []                 [부키]  2017     7
#
#                                                  카테고리  \
# 0                             국내도서 소설시희곡 한국소설 한국 장편소설
# 1   국내도서 경제 경영 투자재테크 재테크일반 국내도서 미디어 추천 중앙일보 국내도서  ...
# 2               국내도서 수험서 자격증 경제금융회계물류 경제경영 기타자격증  관리사
# 3   국내도서 소설시희곡 장르소설 판타지 국내도서 소설시희곡 한국소설 한국 장편소설 국내...
# 4   국내도서 사회 정치 사회학 사회사사회문화 국내도서 인문 윤리학 국내도서 미디어 추천...
# 5   국내도서 소설시희곡 장르소설 판타지 국내도서 소설시희곡 한국소설 한국 장편소설 국내...
# 6   국내도서 소설시희곡 한국소설 한국 장편소설 국내도서  올해의 책 년 올해의 책 후보...
# 7                             국내도서 경제 경영 경제 경제상식경제이야기
# 8   국내도서 소설시희곡 영미소설 영미 장편소설 국내도서 미디어 추천 한겨레 국내도서  ...
# 9   국내도서 소설시희곡 영미소설 영미 장편소설 국내도서  올해의 책 년 올해의 책 후보...
# 10              국내도서 사회 정치 사회학 사회사상사 국내도서 인문 철학사상 관념론
# 11                            국내도서 소설시희곡 영미소설 영미 장편소설
# 12  국내도서 소설시희곡 장르소설 추리미스터리 국내도서 소설시희곡 장르소설 공포스릴러 국...
# 13  국내도서 소설시희곡 장르소설  국내도서 소설시희곡 한국소설 한국 단편소설 국내도서 ...
# 14                       국내도서 역사 동양사동양문화 중국역사문화 중국고대사
# 15                            국내도서 대학교재 경상계열 경영학 국제경영
# 16  국내도서 소설시희곡 장르소설  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 ...
# 17                              국내도서 역사 한국사한국문화 한국사일반
# 18                               국내도서 대학교재 경상계열 광고마케팅
# 19     국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 해외문학상 수상작 부커상 수상작
# 20                            국내도서 인문 인문교양 교양으로 읽는 인문
# 21                               국내도서 건강 취미 건강에세이건강기타
# 22  국내도서 자연과학 생명과학 생물학 국내도서 자연과학 생명과학 유전자진화바이러스 국내...
# 23  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 행복한아침독서책둥이 추천  년 ...
# 24                               국내도서 예술 건축 건축이론비평건축사
# 25                       국내도서 대학교재 예체능문화기타 계열 식품영양학조리
# 26                         국내도서 대학교재 대학출판부 이화여자대학교출판부
# 27                            국내도서 경제 경영 경제 경제상식경제이야기
# 28  국내도서 경제 경영 경영 경영일반 국내도서  올해의 책 년 올해의 책 후보도서 국내...
# 29  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 국내문학상 수상작 대산문학상 수...
# 30                                   국내도서 대학교재 인문학 계열
# 31                            국내도서 소설시희곡 한국소설 한국 단편소설
# 32  국내도서 소설시희곡 장르소설 판타지 국내도서 소설시희곡 테마소설 영화와 드라마 원작...
# 33            국내도서 대학교재 자연과학 계열 수학 국내도서 자연과학 수학 확률통계학
# 34  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 미디어 추천 한겨레 국내도서  ...
# 35      국내도서 경제 경영 경제 국제경제금융화폐 국내도서 경제 경영 투자재테크 재테크일반
# 36  국내도서 사회 정치 사회비평비판 국제사회비평 국내도서 사회 정치 사회학 사회사사회문...
# 37   국내도서 경제 경영 투자재테크 재테크일반 국내도서  올해의 책 년 올해의 책 후보도서
# 38  국내도서 경제 경영 경제 각국 경제경제사전망 경제전망 국내도서 세종도서구문화체육관광...
# 39                            국내도서 소설시희곡 한국소설 한국 장편소설
# 40  국내도서 소설시희곡 한국소설 한국 단편소설 국내도서 미디어 추천 한겨레 국내도서  ...
# 41  국내도서 인문 심리 주제로 읽는 심리학 쉽게 읽는 심리학 국내도서 인문 심리 주제로...
# 42  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 국내문학상 수상작 대산문학상 수...
# 43                                  국내도서 자기계발 성공학경력관리
# 44  국내도서 사회 정치 사회학 사회학일반 국내도서 사회 정치 생태환경 환경문제 국내도서...
# 45  국내도서 인문 심리 심리학 이론 국내도서 미디어 추천 조선일보 국내도서  올해의 책...
# 46                        국내도서 대학교재 의약학간호 계열 의학 기타 교재
# 47  국내도서 사회 정치 사회비평비판 노동문제 국내도서 사회 정치 정치외교 서양정치사상정...
# 48                               국내도서  모바일 오피스 활용  엑셀
# 49  국내도서 경제 경영 경제 각국 경제경제사전망 경제전망 국내도서 세종도서구문화체육관광...
#
#                                                  저자소개  \
# 0   [서울, 태어났다, 판타스틱, 드림, 드림, 드림, 발표, 하며, 작품, 활동, 시...
# 1   [한인, 기업, 최초, 글로벌, 외식, 그룹, 인, 회장, 이다, 한국, 전, 세계...
# 2   [고려대학교, 경영학, 고려대학교, 대학원, 경영학, 과를, 졸업, 회계학, 전공,...
# 3   [부산, 태어났다, 부산, 대, 재료공학, 공부, 하고, 반도체, 엔지니어, 했다,...
# 4   [이후, 한국, 정의, 열풍, 불러일으켰다, 세, 최연, 소, 하버드, 대학교, 교...
# 5   [부산, 태어났다, 부산, 대, 재료공학, 공부, 하고, 반도체, 엔지니어, 했다,...
# 6   [화만, 화, 소설, 넘나, 들며, 온갖, 이야기, 써, 나가는, 전, 천후, 스토...
# 7   [투자자, 이자, 자수, 성가, 한, 백만장자, 개, 국어, 넘는, 언어, 출, 간...
# 8   [전, 세계, 뜨거운, 관심, 사랑, 받고, 있는, 한국, 계, 미국인, 소설가, ...
# 9   [영국, 요크셔, 출신, 동화작가, 겸, 소설가, 다, 출, 간, 한, 첫, 소설,...
# 10  [이후, 한국, 정의, 열풍, 불러일으켰다, 세, 최연, 소, 하버드, 대학교, 교...
# 11  [전, 세계, 뜨거운, 관심, 사랑, 받고, 있는, 한국, 계, 미국인, 소설가, ...
# 12  [회, 황금가지, 타임, 리프, 공모전, 오버, 랩, 나이프, 나이프, 우수상, 회...
# 13  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 14  [상해, 사회과학, 원, 역사, 연구소, 연구원, 상해시, 중학교, 교사, 길림, ...
# 15                                                 []
# 16  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 17                                                 []
# 18  [일본, 게이오, 대학, 상학, 연, 마케팅, 연구, 하였고, 소, 비시, 장, 에...
# 19  [늦은, 태어났다, 연세대, 국문과, 졸업, 한, 뒤, 문학과사회, 시를, 발표, ...
# 20  [겨울, 출, 간, 한, 첫, 책, 지적, 대화, 위, 한, 넓고, 얕은, 지식, ...
# 21                                                 []
# 22  [방송, 계, 퓰리처상, 불리는, 피버디상, 수상한, 과학, 전, 문, 기자, 넘게...
# 23  [서울, 태어났다, 서강대, 학교, 사회학, 철학, 공부, 했고, 한국, 영화아카데...
# 24                                                 []
# 25                                                 []
# 26  [곰, 브리, 치는, 오스트리아, 빈, 태어났다, 미술사, 박사학위, 취득, 하였고...
# 27  [투자자, 이자, 자수, 성가, 한, 백만장자, 개, 국어, 넘는, 언어, 출, 간...
# 28  [래, 리, 보시, 디, 는, 포춘, 선정, 한, 기술, 제조업, 계, 리더, 인,...
# 29  [늦은, 태어났다, 연세대, 국문과, 졸업, 한, 뒤, 문학과사회, 시를, 발표, ...
# 30  [김성은, 주, 히든, 그레이스, 대표, 현재, 데이터, 분석, 머신, 러닝, 프로...
# 31  [눈, 많이, 내리던, 날, 서울, 태어났다, 낮, 엔, 하고, 밤, 엔, 글, 쓰...
# 32  [새로운, 판매, 기록, 세우고, 수많은, 상, 수상한, 해리, 포터, 시리즈, 작...
# 33  [성균관대, 학교, 수학과, 학사, 석사, 박사, 통계학, 전공, 학위, 취득, 하...
# 34  [소설가, 전남, 함평, 출생, 이다, 대학, 시절, 에는, 국문과, 친구, 소설,...
# 35  [간, 유통업, 계, 종사, 하며, 대기업, 직장인, 살았다, 휴일, 근무, 며, ...
# 36  [미국, 보스턴, 출생, 했다, 록스버리, 라틴, 스쿨, 하버드, 대학교, 졸업, ...
# 37  [글, 쓰기, 시작, 했다, 교육, 자기계발, 인문학, 다양한, 분야, 서른, 권,...
# 38  [보스턴, 대학, 교수, 이며, 매사추세츠, 공과대학, 디지털, 경제, 이니셔티브,...
# 39  [대학, 컴퓨터공학, 전공, 하고, 소프트웨어, 개발자, 했다, 번의, 입사, 퇴사...
# 40  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 41                                                 []
# 42  [삼색, 고양이, 날, 태어나, 삼색, 고양이, 고등어, 고양이, 사는, 소설가, ...
# 43  [고등학교, 시절, 수능, 공부, 하는, 대신, 영어, 공부, 하여, 토익, 성적,...
# 44  [생태학, 시대, 어머니, 이자, 환경, 중요성, 깨워, 준, 레이첼, 카슨, 은,...
# 45  [토론토, 대학교, 심리학, 교수, 임상심리학, 가지, 인생, 법칙, 일약, 베스트...
# 46                                                 []
# 47  [일본, 태어나, 해방, 귀국, 해서, 고등학교, 대구, 살았다, 서울대학교, 상과...
# 48  [현재, 한남, 대학교, 국제, 교육, 센터, 교수, 재직, 중이, 며, 대전, 지...
# 49  [보스턴, 대학, 교수, 이며, 매사추세츠, 공과대학, 디지털, 경제, 이니셔티브,...
#
#                                                   책소개  \
# 0   [창비, 장편소설, 상, 한국, 일보, 문학상, 수상, 작가, 정세랑, 두번째, 장...
# 1   [연속, 최, 장기, 베스트셀러, 만, 깨어있는, 독자, 선택, 한, 경제, 경영,...
# 2   [회계, 원리, 는, 모든, 회계, 기초, 입니다, 본, 서는, 회계, 관, 한, ...
# 3   [여기는, 잠들어야만, 입장, 할, 수, 있는, 달러, 구트, 꿈, 백화점, 입니다...
# 4   [마이클, 샌델, 만의, 신간, 공정하다는, 착각, 출, 간, 샌델, 기울어진, 사...
# 5   [만, 독자, 사로잡은, 달러, 구트, 꿈, 백화점, 두, 번째, 이야기, 어느덧,...
# 6   [최고, 재미, 감동, 선사, 하는, 힐링, 소설, 원조, 주요, 서점, 종합, 베...
# 7   [미국, 아마존, 금융, 사업, 분야, 위, 국내, 유명, 서점, 간, 종합, 베스...
# 8   [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 9   [밤, 시, 죽기, 전, 에만, 열리는, 마법, 도서관, 인생, 두, 번째, 기회,...
# 10  [한국, 정의, 열풍, 불러일으킨, 마이클, 샌델, 은, 구제, 금융, 대리, 출산...
# 11  [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 12  [안전가옥, 쇼트, 시리즈, 두, 번째, 책, 조예은, 작가, 단, 편집, 이다, ...
# 13  [우아한, 계보, 후지, 난, 겨울, 바이오, 센서, 만드는, 과학, 도, 였던, ...
# 14  [총, 권, 구성, 되어, 있으며, 원시, 사회, 에서부터, 청나라, 멸망, 중국,...
# 15  [책, 은, 국제, 경영, 관, 한, 이론, 서, 입니다, 국제, 경영, 기초, 적...
# 16  [김, 초엽, 첫, 장편소설, 간절히, 기다려, 온, 이야기, 이미, 폭넓은, 독자...
# 17                                                 []
# 18  [마케팅, 전략, 은, 커, 교수, 맥러, 그린, 교수, 공저, 한, 번역, 한, ...
# 19  [인터내셔널, 부커상, 산클레멘테, 문학상, 수상작, 전세계, 주목, 한, 한강, ...
# 20  [지적, 대화, 하기, 위해, 서, 깔려, 있어야, 하는, 가장, 기본, 지식, 시...
# 21  [현대인, 위, 한, 건강, 생활, 가이드, 시리즈, 좋은, 음식, 올바른, 식사,...
# 22  [방송, 계, 퓰리처상, 피버디상, 수상자, 룰루, 밀러, 사랑, 혼돈, 과학, 적...
# 23  [공감, 불능, 사회, 차가, 움, 녹이는, 아몬드, 매혹, 적, 인, 문체, 독특...
# 24                                                 []
# 25  [세계, 각국, 음식, 문화, 대한, 연구, 는, 인간, 의식, 구조, 삶, 방식,...
# 26  [번역본, 현대, 시, 지각, 이론, 입, 각하, 회화, 적, 재현, 역사, 심리,...
# 27  [미국, 아마존, 금융, 사업, 분야, 위, 국내, 유명, 서점, 간, 종합, 베스...
# 28  [똑같이, 우수한, 비, 전과, 전략, 수립, 하였음에도, 불구, 하고, 기업, 은...
# 29  [생각, 하면, 견딜, 수, 있나, 가슴, 활활, 일어나는, 불, 없다면, 기어이,...
# 30  [분석, 방법, 결과, 표, 작성, 해석, 방법, 논문, 초심자, 해야, 할, 하지...
# 31  [먼저, 죽는다면나는, 먹을, 거, 래야, 없이도, 죽지, 않고, 살, 수, 있어,...
# 32  [해리, 포터, 세대, 해리, 포터, 세대, 위, 한, 해리, 포터, 세대, 의한,...
# 33  [빅데이터, 시대, 이제, 는, 통계, 적, 사고, 경쟁력, 이다, 는, 살아가면서...
# 34  [다시, 정, 유정, 자기애, 늪, 빠진, 삶은, 위태, 로운, 압도, 적, 서사,...
# 35  [베스트셀러, 아들, 돈, 공부, 해야, 한다, 만, 부, 기념, 골드, 에디, 션...
# 36  [민족, 은, 민족, 정복, 지배, 대상, 전락, 하고, 말았는가, 원주민, 은, ...
# 37  [석유, 는, 데이터, 부동산, 은, 데이터, 센터, 코로나, 가속, 화, 한, 차...
# 38  [차, 산업혁명, 주인공, 은, 플랫폼, 축하, 거나, 활용, 하는, 자가, 될, ...
# 39  [받아들여지고, 있다는, 느낌, 이렇게, 슬프고도, 좋을, 줄, 이야, 브런치, 북...
# 40  [사랑, 입자, 타고, 낯선, 세계, 떠, 도, 는, 경이, 롭고, 아름다운, 우주...
# 41  [옥스퍼드, 대학, 입문, 총서, 시리즈, 심리학, 개론, 서, 두뇌, 대한, 과학...
# 42  [백, 감싸안으며, 이어지는, 사랑, 숨, 기록, 쇼코, 미소, 내게, 무, 해한,...
# 43  [현실, 타협, 하는, 삶, 에서도, 행복, 만드는, 방법, 꿈꾸기에는, 불안하고,...
# 44  [세기, 가장, 큰, 영향력, 미친, 책, 컬, 지는, 침묵, 봄, 개정판, 이다,...
# 45  [피터슨, 돌아왔다, 전, 세계, 젊은이, 열광, 시킨, 인생, 법칙, 완결, 판,...
# 46  [분광분석, 분리, 분석, 첫, 단계, 로서, 기, 기분, 석, 학, 약학, 교육,...
# 47  [한국, 최고, 마르크스, 경제학자, 김수행, 교수, 듣는, 자본론, 특강, 자본론...
# 48  [버전, 담은, 첫, 교재, 강의, 경력, 깊고, 풍부한, 전문, 강, 사진, 시험...
# 49  [차, 산업혁명, 주인공, 은, 플랫폼, 축하, 거나, 활용, 하는, 자가, 될, ...
#
#                                                    목차  \
# 0                                  [지구, 한아, 뿐, 작가, 말]
# 1   [쇄, 기념, 개정, 증보, 판, 내면, 서, 프롤로그, 돈, 은, 인격, 체다, ...
# 2   [장, 회계, 기초, 이론, 절, 회계, 기초, 회, 계란, 인가, 회계, 정보, ...
# 3   [작가, 말, 프롤로그, 번째, 제자, 유서, 깊은, 가게, 주문, 하신, 꿈, 은...
# 4   [서론, 대학, 입시, 능력, 주의, 입시, 윤리, 능력, 지표, 따내기, 승자, ...
# 5   [프롤로그, 달러, 구트, 다락방, 장, 페니, 첫, 번째, 연봉, 협상, 장, 민...
# 6   [산, 해, 진미, 도시락, 제이, 에스, 오브, 제이, 에스, 삼각김밥, 용도, ...
# 7   [머리말, 람보르기니, 예언, 실현, 되다, 프롤로그, 부자, 되는, 길, 에는, ...
# 8                                                  []
# 9                                                  []
# 10  [책, 쏟아진, 찬사, 한국어, 판, 서, 문장, 정의, 란, 옳고, 그름, 판단,...
# 11                                                 []
# 12  [초대, 습지, 사랑, 칵테일, 러브, 좀비, 오버, 랩, 나이프, 나이프, 작품,...
# 13  [순례, 은, 돌아오지, 않는가, 스펙트럼, 공생, 가설, 빛, 속도, 갈, 수, ...
# 14  [발간, 즈음, 하여, 발, 간사, 꿈, 추구, 독자, 위해, 엮, 은, 중국, 역...
# 15  [글로벌화, 글로벌, 경영, 글로벌화, 글로벌, 경영, 이해, 글로벌, 화란, 인가...
# 16  [프롤로그, 장, 모스, 바나, 장, 프림, 빌리지, 장, 지구, 끝, 온실, 작가...
# 17  [프롤로그, 일제시대, 종교, 정책, 보천교, 보천교, 민족, 독립운동, 식, 민권...
# 18  [장, 마케팅, 이란, 인가, 절, 마케팅, 이란, 절, 마케팅, 탄생, 의미, 절...
# 19  [채식주의자, 몽고반점, 나무, 불꽃, 새로, 쓴, 작가, 말, 작가, 말, 수록,...
# 20  [프롤로그, 책, 읽는, 방법, 준비, 운동, 세계, 구조, 화, 판단, 중, 지,...
# 21  [개혁, 필요한, 이유, 식생활, 영성, 건강, 개혁, 셋째, 천사, 기별, 합당,...
# 22  [프롤로그, 별, 머리, 담근, 소년, 섬, 선지자, 신, 없는, 막간, 극, 꼬리...
# 23                                                 []
# 24  [교육, 시설, 건축, 위, 한, 설계, 이론, 유형, 학습, 생활, 위, 한, 공...
# 25  [식생활, 문화, 이해, 하기, 음식, 문화, 역사, 선사시대, 음식, 문화, 역사...
# 26  [서문, 서론, 심리학, 양식, 수수께끼, 부, 유사성, 한계, 빛, 으로부터, 물...
# 27  [머리말, 람보르기니, 예언, 실현, 되다, 프롤로그, 부자, 되는, 길, 에는, ...
# 28  [부, 실행, 력, 인가, 장, 실행, 력, 없는, 비전은, 비극, 이다, 경영, ...
# 29  [부, 새, 결정, 실, 폭설, 새, 남은, 빛, 나무, 부, 밤, 작별, 하지, ...
# 30  [논문, 통계, 분석, 기초, 편, 사용, 할까, 요, 누가, 활용, 하면, 좋을까...
# 31                                    [구의, 증명, 작가, 말]
# 32                                                 []
# 33  [기술통계학, 자료, 정리, 요약, 도표, 이용, 한, 자료, 정리, 그림, 이용,...
# 34  [부, 그녀, 오리, 장, 장, 장, 부, 그녀, 는, 일까, 장, 장, 장, 부,...
# 35  [책, 쏟아진, 찬사, 만, 부, 기념, 골드, 에디, 션, 서문, 지금, 는, 다...
# 36  [친애하는, 한국, 독자, 드리는, 편지, 제레드, 다이아몬드, 증보, 판, 부쳐,...
# 37  [프롤로그, 는, 은, 는, 준비, 해야, 하는가, 새로운, 부가, 오고, 인공, ...
# 38  [한국어, 판, 서문, 우려, 스러운, 한국, 플랫폼, 경쟁력, 머리말, 플랫폼, ...
# 39  [서점, 은, 모습, 이어야, 할까, 이제, 더, 는, 울, 지, 않아도, 된다오,...
# 40  [최후, 라이, 오니, 마리, 춤, 로라, 숨, 그림자, 오래된, 협약, 인지, 공...
# 41  [심리학, 이란, 인가, 공부, 할, 인가, 두뇌, 속, 들어오게, 되는가, 인지,...
# 42                             [부, 부, 부, 부, 부, 작가, 말]
# 43  [추천사, 청춘, 한, 줄기, 빛, 될, 수, 있다면, 청춘, 머뭇거리, 기, 에는...
# 44  [감사, 글, 서문, 린다, 리, 내일, 위, 한, 우화, 참아야, 하는, 의무, ...
# 45  [법칙, 기존, 제도, 창의, 적, 변화, 함부로, 깎아내리지, 마라, 법칙, 내,...
# 46  [장, 분광분석법, 장, 분리, 분석, 법, 장, 전기화학, 분석, 법, 장, 원료...
# 47  [자본론, 대하, 자본주의, 사회, 는, 사라지지, 않을까, 인류, 경제, 사회, ...
# 48  [머리말, 시험, 소개, 시험, 인터페이스, 안내, 책, 학습, 방법, 목차, 화면...
# 49  [한국어, 판, 서문, 우려, 스러운, 한국, 플랫폼, 경쟁력, 머리말, 플랫폼, ...
#
#                                                 출판사서평  \
# 0   [점점, 줄어드는, 페이지, 보며, 아쉬워, 무거워진, 눈꺼풀, 참으며, 책, 읽는...
# 1   [는, 정말, 필요한, 나누려는, 사람, 이다, 최근, 사이, 수만, 명의, 사람,...
# 2   [회계, 원리, 회계, 원리, 는, 모든, 회계, 기초, 입니다, 본, 서는, 회계...
# 3   [텀블벅, 펀딩, 달성, 출, 간, 주, 연속, 종합, 베스트셀러, 위, 독자, 별...
# 4   [능력, 주의, 는, 공정하게, 작동, 하는가, 공정함, 정의, 란, 공식, 은, ...
# 5   [내내, 베스트셀러, 위, 독자, 뽑은, 최고, 힐링, 판타지, 잠들어야만, 입장,...
# 6   [원, 플러스, 원, 기쁨, 삼각김밥, 모양, 슬픔, 만, 원, 번의, 폭소, 터지...
# 7   [부자, 되기, 플랜, 속지, 마라, 지금, 까지의, 부자, 되기, 책, 이야기, ...
# 8   [회복, 연민, 대한, 강력한, 이야기, 버락, 오바마, 미국, 전, 대통령, 전,...
# 9   [영국, 아마존, 종합, 베스트셀러, 위, 미국, 아마존, 뉴욕타임스, 선데이타임스...
# 10  [정의, 둘러싼, 위대한, 철학자, 과의, 대화, 글로벌, 금융, 위기, 이후, 억...
# 11  [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 12  [토록, 생생한, 어둠, 감정, 은, 곧잘, 무시, 당한다, 여성, 이라서, 자식,...
# 13  [젊은, 소설가, 첫, 작품집, 이라고는, 믿기지, 않을, 정도, 매끄럽게, 이어지...
# 14  [일반, 독자, 위, 한, 중국, 역사, 문화, 집대성, 한, 백과사전, 중국, 저...
# 15                                                 []
# 16  [악마, 식물, 내, 정원, 자라고, 있는데, 거, 멸망, 징조, 아니야, 덩굴식물...
# 17                                                 []
# 18                                                 []
# 19  [폭력, 아름다, 움, 처절한, 공존, 새롭게, 읽히는, 한강, 소설, 힘년, 창비...
# 20  [만, 부, 밀리언셀러, 지대, 넓, 얕, 최초, 개정, 증보, 판, 지적, 대화,...
# 21                                                 []
# 22  [워싱턴포스트, 북, 라이엇, 내서, 널퍼, 블릭, 라디오, 시카고, 트리뷴, 스미...
# 23  [감정, 느끼지, 못, 하는, 소년, 특별한, 성장, 아몬드, 주인공, 윤재, 는,...
# 24                                                 []
# 25  [식생활, 이란, 인간, 생활, 중, 생명, 유지, 생체, 활동, 필요한, 영양분,...
# 26  [심리학, 철학, 문, 화사, 전반, 가로지르는, 곰, 브리, 치, 미술사, 연구,...
# 27  [부자, 되기, 플랜, 속지, 마라, 지금, 까지의, 부자, 되기, 책, 이야기, ...
# 28                                                 []
# 29  [이상하지, 눈, 은, 하늘, 저런, 게, 내려오지, 작별, 지, 않는다는, 소설가...
# 30  [논문, 통계, 분석, 기초, 편, 에서는, 통계, 분석, 하기, 전, 알아야, 하...
# 31  [상상, 가능, 케, 하는, 사랑, 그런, 사랑, 가능, 케, 하는, 상상, 여자,...
# 32  [해리, 포터, 키즈, 완벽하게, 구현, 한, 롤링, 마법, 세계, 시대, 가장, ...
# 33                                                 []
# 34  [행복, 은, 덧셈, 아니야, 행복, 은, 뺄셈, 이야, 완전해질, 불행, 가능성,...
# 35  [경제, 는, 사람, 사이, 실생활, 밀착, 형, 경제, 수업, 아들, 돈, 공부,...
# 36  [인류, 문명, 수수께끼, 새로운, 풀어, 낸, 명, 개정, 신판, 특별, 증보, ...
# 37  [석유, 는, 데이터, 부동산, 은, 데이터, 센터, 코로나, 가속, 화, 한, 차...
# 38  [세계, 적, 인, 석, 학, 저술, 한, 플랫폼, 비즈니스, 안내서, 포브스, 선...
# 39  [먼저, 읽은, 독자, 요청, 종이, 책, 다시, 태어난, 소설, 출, 간, 전자책...
# 40  [사랑, 끝내, 이해, 할, 수, 없는, 에게도, 있지, 않나요, 빛, 속도, 갈,...
# 41                                                 []
# 42  [슬픔, 위로, 하고, 감싸주는, 더, 큰, 슬픔, 힘, 오정희, 소설가, 증조, ...
# 43  [꿈, 현실, 사이, 방황, 하는, 대를, 위, 한, 청춘, 사용설명서, 꿈, 좇자...
# 44  [세상, 바꾼, 인물, 세상, 변화, 시킨, 책, 더, 설명, 필요, 없는, 세기,...
# 45  [시대, 가장, 논쟁, 적, 이고, 영향력, 있는, 지식인, 가지, 인생, 법칙, ...
# 46  [의약품, 기, 기분, 석, 학, 분권, 한, 후의, 첫, 번째, 개정, 분권, 후...
# 47  [한국, 최고, 마르크스, 경제학자, 김수행, 교수, 듣는, 자본론, 특강, 최고,...
# 48                                                 []
# 49  [세계, 적, 인, 석, 학, 저술, 한, 플랫폼, 비즈니스, 안내서, 포브스, 선...
#
#                                                   추천사
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [역시, 마이클, 샌델답다, 에는, 시대, 가장, 예민한, 이슈, 수술, 메스, 대...
# 5                                                  []
# 6   [서울역, 홈리스, 지내면서도, 안위, 보다는, 지갑, 잃어버린, 낯선, 부인, 안...
# 7   [부동산, 스터디, 우석, 신사임당, 이상한, 리뷰, 앨리스, 단, 희, 인, 플루...
# 8   [올해, 최고, 책, 록산, 게이, 작가, 세기, 견뎌내고, 번영, 이룬, 재일한국...
# 9                                                  []
# 10                                                 []
# 11  [올해, 최고, 책, 록산, 게이, 작가, 세기, 견뎌내고, 번영, 이룬, 재일한국...
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16  [간절히, 원, 해온, 은, 울, 고, 난, 뒤, 에야, 알, 게, 되는, 걸까, ...
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22  [내, 맘대로, 올해, 책, 물고기, 는, 존재, 하지, 않는다, 책장, 덮는, 순...
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27  [부동산, 스터디, 우석, 신사임당, 이상한, 리뷰, 앨리스, 단, 희, 인, 플루...
# 28                                                 []
# 29  [작가, 소재, 택하, 는, 아니라, 반, 대, 일지, 도, 모른다는, 생각, 한강...
# 30                                                 []
# 31                                                 []
# 32                                                 []
# 33                                                 []
# 34                                                 []
# 35  [한때, 좋은, 대학, 만, 가면, 앞길, 훤히, 열릴, 이라는, 믿음, 진실, 이...
# 36                                                 []
# 37                                                 []
# 38  [세기, 후반, 등장, 한, 디지털, 혁명, 인터넷, 혁명, 은, 모바일, 혁명, ...
# 39  [내, 맘대로, 올해, 책, 모자라지도, 하지도, 않은, 적당한, 온도, 따뜻함과,...
# 40  [김, 초엽, 눈부신, 데뷔, 이후, 줄곧, 두, 번째, 소설, 집, 기다려, 왔다...
# 41                                                 []
# 42  [태생, 지를, 빌려, 삼천이, 새, 비, 서로, 부르며, 한, 세상, 살, 냈던,...
# 43  [책, 추천사, 의뢰, 받으면서, 떠오른, 생각, 은, 였습니다, 청춘, 한, 줄기...
# 44                                                 []
# 45  [지금, 세상, 은, 조던, 피터슨, 필요, 한다, 더글러스, 머리, 유럽, 죽음,...
# 46                                                 []
# 47                                                 []
# 48                                                 []
# 49  [세기, 후반, 등장, 한, 디지털, 혁명, 인터넷, 혁명, 은, 모바일, 혁명, ...

# %%
df['서평+추천사'] = df['출판사서평'].fillna('') + df['추천사'].fillna('')
df
# Out:
#     순위                                                도서명  \
# 0    1                             [지구, 한아, 뿐, 정세랑, 장편소설]
# 1    2               [돈, 속성, 최, 상위, 부자, 말, 하는, 돈, 대한, 모든]
# 2    3                                        [회계, 원리, 판]
# 3    4  [달러, 구트, 꿈, 백화점, 주문, 하신, 꿈, 은, 매진, 입니다, 이미, 장편소설]
# 4    5            [공정하다는, 착각, 능력, 주의, 는, 같은, 기회, 제공, 하는가]
# 5    6                     [달러, 구트, 꿈, 백화점, 단골, 손님, 찾습니다]
# 6    7                                         [불편한, 편의점]
# 7    8    [부의, 추월, 차선, 부자, 말, 해, 주지, 않는, 진정한, 부를, 얻는, 방법]
# 8    9                                              [파친코]
# 9   10                                      [미드나잇, 라이브러리]
# 10  11                                        [정의, 란, 인가]
# 11  12                                 [파친코, 이민, 진, 장편소설]
# 12  13                                      [칵테일, 러브, 좀비]
# 13  14                      [빛, 속도, 갈, 수, 없다면, 김, 초엽, 소설]
# 14  15                                        [중국, 말, 한다]
# 15  16                                      [글로벌, 경영, 제판]
# 16  17                                        [지구, 끝, 온실]
# 17  18                           [잃어버린, 역사, 회복, 위, 한, 시작]
# 18  19                                          [마케팅, 전략]
# 19  20                          [채식주의자, 한강, 연작, 소설, 장편소설]
# 20  21  [지적, 대화, 위, 한, 넓고, 얕은, 지식, 한, 권, 편안하게, 즐기는, 지식...
# 21  22                             [좋은, 음식, 올바른, 식사, 개정판]
# 22  23  [물고기, 는, 존재, 하지, 않는다, 상실, 사랑, 숨어, 있는, 삶, 질서, 관...
# 23  24                                 [아몬드, 손, 원평, 장편소설]
# 24  25                 [교육, 시설, 건축, 위, 한, 설계, 디테일, 도해, 집]
# 25  26                                       [음식, 세계, 문화]
# 26  27                    [예술, 환영, 회화, 적, 재현, 심리학, 적, 연구]
# 27  28    [부의, 추월, 차선, 부자, 말, 해, 주지, 않는, 진정한, 부를, 얻는, 방법]
# 28  29                                       [실행, 집중, 하라]
# 29  30                            [작별, 하지, 않는다, 한강, 장편소설]
# 30  31                [한번, 통과, 하는, 논문, 결과, 표, 작성, 해석, 방법]
# 31  32                                  [구의, 증명, 최진영, 소설]
# 32  33                                   [권, 마법사, 돌, 개정판]
# 33  34                           [이공, 계, 생, 위, 한, 확률, 통계]
# 34  35                             [완전한, 행복, 정, 유정, 장편소설]
# 35  36         [아들, 돈, 공부, 해야, 한다, 억, 부자, 아빠, 현실, 경제, 수업]
# 36  37                                       [총, 균, 쇠, 판]
# 37  38                                            [미래, 부]
# 38  39     [플랫폼, 레볼루션, 차, 산업혁명, 시대, 지배, 할, 플랫폼, 비즈니스, 모든]
# 39  40                             [어서, 오세요, 남동, 서점, 입니다]
# 40  41                        [방금, 떠나온, 세계, 김, 초엽, 소설, 집]
# 41  42                                      [심리학, 이란, 인가]
# 42  43                                 [밝은, 밤, 최은영, 장편소설]
# 43  44               [미래, 진로, 고민, 하는, 대가, 준비, 해야, 할, 개정판]
# 44  45                                            [침묵, 봄]
# 45  46                     [질서, 너머, 인생, 단계, 나아가는, 가지, 법칙]
# 46  47                            [의약품, 기, 기분, 석, 학, 개정판]
# 47  48                                          [자본론, 공부]
# 48  49                                   [일만, 합격, 하는, 엑셀]
# 49  50     [플랫폼, 레볼루션, 차, 산업혁명, 시대, 지배, 할, 플랫폼, 비즈니스, 모든]
#
#                        저자                  출판사  발행연도  대출횟수  \
# 0                   [정세랑]                 [난다]  2019    19
# 1                   [김승호]        [스노우, 폭스, 북스]  2020    19
# 2                   [김기동]               [샘앤북스]  2017    18
# 3                    [이미]            [팩토리, 나인]  2020    18
# 4                      []            [와이즈, 베리]  2020    17
# 5                    [이미]            [팩토리, 나인]  2021    16
# 6                   [김호연]          [나무, 옆, 의자]  2021    15
# 7                      []                 [토트]  2022    14
# 8                      []             [문학사, 상]  2018    13
# 9                      []        [인, 플루, 엔, 셜]  2021    13
# 10                     []                [김영사]  2010    12
# 11                     []             [문학사, 상]  2018    12
# 12                  [조예은]               [안전가옥]  2020    12
# 13                [김, 초엽]                 [허블]  2019    12
# 14           [양산, 췬, 외지음]    [신, 원, 문, 화사, 신원]  2008    12
# 15                   [이철]                 [학현]  2019    11
# 16                [김, 초엽]           [자이언트, 북스]  2021    11
# 17     [노목, 천연, 계, 탐, 사관]                [시조사]  2003    11
# 18                [박철, 주]                 [형설]  2016    11
# 19                   [한강]                 [창비]  2009    11
# 20                [채, 사장]             [한빛, 비즈]  2015    11
# 21                     []                [시조사]  2009    11
# 22                     []                  [곰]  2021    11
# 23                [손, 원평]                 [창비]  2017    10
# 24                     []            [엠지에이치북스]  2017    10
# 25           [김건희, 외, 지음]                [파워북]  2020    10
# 26                     []            [열, 화, 당]  2003     9
# 27                     []            [토트, 북새통]  2013     9
# 28                     []             [세기, 북스]  2004     9
# 29                   [한강]               [문학동네]  2021     9
# 30  [히든, 그레이스, 논문, 통계, 팀]           [한빛, 아카데미]  2018     9
# 31                  [최진영]               [은행나무]  2015     9
# 32                     []             [문학, 수첩]  2014     8
# 33                [안승, 철]  [한빛, 아카데미, 한빛, 미디어]  2014     8
# 34                [정, 유정]               [은행나무]  2021     8
# 35                [정선, 용]            [알에이치코리아]  2021     8
# 36                     []             [문학사, 상]  2018     8
# 37                     []             [세종, 서적]  2000     8
# 38                     []                 [부키]  2017     8
# 39                [황, 보름]           [클레이, 하우스]  2022     8
# 40                [김, 초엽]                [한겨레]  2021     8
# 41                     []             [스타, 북스]  2011     8
# 42                  [최은영]               [문학동네]  2021     8
# 43                  [김주형]          [미래, 문, 화사]  2021     8
# 44                     []            [에코, 리브르]  2011     8
# 45                     []        [웅진, 지식, 하우스]  2021     7
# 46   [약품, 분, 석, 학, 분, 과회]              [동, 명사]  2020     7
# 47                  [김수행]              [돌, 베개]  2014     7
# 48                  [김경희]  [한빛, 아카데미, 한빛, 미디어]  2017     7
# 49                     []                 [부키]  2017     7
#
#                                                  카테고리  \
# 0                             국내도서 소설시희곡 한국소설 한국 장편소설
# 1   국내도서 경제 경영 투자재테크 재테크일반 국내도서 미디어 추천 중앙일보 국내도서  ...
# 2               국내도서 수험서 자격증 경제금융회계물류 경제경영 기타자격증  관리사
# 3   국내도서 소설시희곡 장르소설 판타지 국내도서 소설시희곡 한국소설 한국 장편소설 국내...
# 4   국내도서 사회 정치 사회학 사회사사회문화 국내도서 인문 윤리학 국내도서 미디어 추천...
# 5   국내도서 소설시희곡 장르소설 판타지 국내도서 소설시희곡 한국소설 한국 장편소설 국내...
# 6   국내도서 소설시희곡 한국소설 한국 장편소설 국내도서  올해의 책 년 올해의 책 후보...
# 7                             국내도서 경제 경영 경제 경제상식경제이야기
# 8   국내도서 소설시희곡 영미소설 영미 장편소설 국내도서 미디어 추천 한겨레 국내도서  ...
# 9   국내도서 소설시희곡 영미소설 영미 장편소설 국내도서  올해의 책 년 올해의 책 후보...
# 10              국내도서 사회 정치 사회학 사회사상사 국내도서 인문 철학사상 관념론
# 11                            국내도서 소설시희곡 영미소설 영미 장편소설
# 12  국내도서 소설시희곡 장르소설 추리미스터리 국내도서 소설시희곡 장르소설 공포스릴러 국...
# 13  국내도서 소설시희곡 장르소설  국내도서 소설시희곡 한국소설 한국 단편소설 국내도서 ...
# 14                       국내도서 역사 동양사동양문화 중국역사문화 중국고대사
# 15                            국내도서 대학교재 경상계열 경영학 국제경영
# 16  국내도서 소설시희곡 장르소설  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 ...
# 17                              국내도서 역사 한국사한국문화 한국사일반
# 18                               국내도서 대학교재 경상계열 광고마케팅
# 19     국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 해외문학상 수상작 부커상 수상작
# 20                            국내도서 인문 인문교양 교양으로 읽는 인문
# 21                               국내도서 건강 취미 건강에세이건강기타
# 22  국내도서 자연과학 생명과학 생물학 국내도서 자연과학 생명과학 유전자진화바이러스 국내...
# 23  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 행복한아침독서책둥이 추천  년 ...
# 24                               국내도서 예술 건축 건축이론비평건축사
# 25                       국내도서 대학교재 예체능문화기타 계열 식품영양학조리
# 26                         국내도서 대학교재 대학출판부 이화여자대학교출판부
# 27                            국내도서 경제 경영 경제 경제상식경제이야기
# 28  국내도서 경제 경영 경영 경영일반 국내도서  올해의 책 년 올해의 책 후보도서 국내...
# 29  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 국내문학상 수상작 대산문학상 수...
# 30                                   국내도서 대학교재 인문학 계열
# 31                            국내도서 소설시희곡 한국소설 한국 단편소설
# 32  국내도서 소설시희곡 장르소설 판타지 국내도서 소설시희곡 테마소설 영화와 드라마 원작...
# 33            국내도서 대학교재 자연과학 계열 수학 국내도서 자연과학 수학 확률통계학
# 34  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 미디어 추천 한겨레 국내도서  ...
# 35      국내도서 경제 경영 경제 국제경제금융화폐 국내도서 경제 경영 투자재테크 재테크일반
# 36  국내도서 사회 정치 사회비평비판 국제사회비평 국내도서 사회 정치 사회학 사회사사회문...
# 37   국내도서 경제 경영 투자재테크 재테크일반 국내도서  올해의 책 년 올해의 책 후보도서
# 38  국내도서 경제 경영 경제 각국 경제경제사전망 경제전망 국내도서 세종도서구문화체육관광...
# 39                            국내도서 소설시희곡 한국소설 한국 장편소설
# 40  국내도서 소설시희곡 한국소설 한국 단편소설 국내도서 미디어 추천 한겨레 국내도서  ...
# 41  국내도서 인문 심리 주제로 읽는 심리학 쉽게 읽는 심리학 국내도서 인문 심리 주제로...
# 42  국내도서 소설시희곡 한국소설 한국 장편소설 국내도서 국내문학상 수상작 대산문학상 수...
# 43                                  국내도서 자기계발 성공학경력관리
# 44  국내도서 사회 정치 사회학 사회학일반 국내도서 사회 정치 생태환경 환경문제 국내도서...
# 45  국내도서 인문 심리 심리학 이론 국내도서 미디어 추천 조선일보 국내도서  올해의 책...
# 46                        국내도서 대학교재 의약학간호 계열 의학 기타 교재
# 47  국내도서 사회 정치 사회비평비판 노동문제 국내도서 사회 정치 정치외교 서양정치사상정...
# 48                               국내도서  모바일 오피스 활용  엑셀
# 49  국내도서 경제 경영 경제 각국 경제경제사전망 경제전망 국내도서 세종도서구문화체육관광...
#
#                                                  저자소개  \
# 0   [서울, 태어났다, 판타스틱, 드림, 드림, 드림, 발표, 하며, 작품, 활동, 시...
# 1   [한인, 기업, 최초, 글로벌, 외식, 그룹, 인, 회장, 이다, 한국, 전, 세계...
# 2   [고려대학교, 경영학, 고려대학교, 대학원, 경영학, 과를, 졸업, 회계학, 전공,...
# 3   [부산, 태어났다, 부산, 대, 재료공학, 공부, 하고, 반도체, 엔지니어, 했다,...
# 4   [이후, 한국, 정의, 열풍, 불러일으켰다, 세, 최연, 소, 하버드, 대학교, 교...
# 5   [부산, 태어났다, 부산, 대, 재료공학, 공부, 하고, 반도체, 엔지니어, 했다,...
# 6   [화만, 화, 소설, 넘나, 들며, 온갖, 이야기, 써, 나가는, 전, 천후, 스토...
# 7   [투자자, 이자, 자수, 성가, 한, 백만장자, 개, 국어, 넘는, 언어, 출, 간...
# 8   [전, 세계, 뜨거운, 관심, 사랑, 받고, 있는, 한국, 계, 미국인, 소설가, ...
# 9   [영국, 요크셔, 출신, 동화작가, 겸, 소설가, 다, 출, 간, 한, 첫, 소설,...
# 10  [이후, 한국, 정의, 열풍, 불러일으켰다, 세, 최연, 소, 하버드, 대학교, 교...
# 11  [전, 세계, 뜨거운, 관심, 사랑, 받고, 있는, 한국, 계, 미국인, 소설가, ...
# 12  [회, 황금가지, 타임, 리프, 공모전, 오버, 랩, 나이프, 나이프, 우수상, 회...
# 13  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 14  [상해, 사회과학, 원, 역사, 연구소, 연구원, 상해시, 중학교, 교사, 길림, ...
# 15                                                 []
# 16  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 17                                                 []
# 18  [일본, 게이오, 대학, 상학, 연, 마케팅, 연구, 하였고, 소, 비시, 장, 에...
# 19  [늦은, 태어났다, 연세대, 국문과, 졸업, 한, 뒤, 문학과사회, 시를, 발표, ...
# 20  [겨울, 출, 간, 한, 첫, 책, 지적, 대화, 위, 한, 넓고, 얕은, 지식, ...
# 21                                                 []
# 22  [방송, 계, 퓰리처상, 불리는, 피버디상, 수상한, 과학, 전, 문, 기자, 넘게...
# 23  [서울, 태어났다, 서강대, 학교, 사회학, 철학, 공부, 했고, 한국, 영화아카데...
# 24                                                 []
# 25                                                 []
# 26  [곰, 브리, 치는, 오스트리아, 빈, 태어났다, 미술사, 박사학위, 취득, 하였고...
# 27  [투자자, 이자, 자수, 성가, 한, 백만장자, 개, 국어, 넘는, 언어, 출, 간...
# 28  [래, 리, 보시, 디, 는, 포춘, 선정, 한, 기술, 제조업, 계, 리더, 인,...
# 29  [늦은, 태어났다, 연세대, 국문과, 졸업, 한, 뒤, 문학과사회, 시를, 발표, ...
# 30  [김성은, 주, 히든, 그레이스, 대표, 현재, 데이터, 분석, 머신, 러닝, 프로...
# 31  [눈, 많이, 내리던, 날, 서울, 태어났다, 낮, 엔, 하고, 밤, 엔, 글, 쓰...
# 32  [새로운, 판매, 기록, 세우고, 수많은, 상, 수상한, 해리, 포터, 시리즈, 작...
# 33  [성균관대, 학교, 수학과, 학사, 석사, 박사, 통계학, 전공, 학위, 취득, 하...
# 34  [소설가, 전남, 함평, 출생, 이다, 대학, 시절, 에는, 국문과, 친구, 소설,...
# 35  [간, 유통업, 계, 종사, 하며, 대기업, 직장인, 살았다, 휴일, 근무, 며, ...
# 36  [미국, 보스턴, 출생, 했다, 록스버리, 라틴, 스쿨, 하버드, 대학교, 졸업, ...
# 37  [글, 쓰기, 시작, 했다, 교육, 자기계발, 인문학, 다양한, 분야, 서른, 권,...
# 38  [보스턴, 대학, 교수, 이며, 매사추세츠, 공과대학, 디지털, 경제, 이니셔티브,...
# 39  [대학, 컴퓨터공학, 전공, 하고, 소프트웨어, 개발자, 했다, 번의, 입사, 퇴사...
# 40  [소설가, 년생, 포스텍, 화학, 전공, 하고, 생화학, 석사, 학위, 받았, 다년...
# 41                                                 []
# 42  [삼색, 고양이, 날, 태어나, 삼색, 고양이, 고등어, 고양이, 사는, 소설가, ...
# 43  [고등학교, 시절, 수능, 공부, 하는, 대신, 영어, 공부, 하여, 토익, 성적,...
# 44  [생태학, 시대, 어머니, 이자, 환경, 중요성, 깨워, 준, 레이첼, 카슨, 은,...
# 45  [토론토, 대학교, 심리학, 교수, 임상심리학, 가지, 인생, 법칙, 일약, 베스트...
# 46                                                 []
# 47  [일본, 태어나, 해방, 귀국, 해서, 고등학교, 대구, 살았다, 서울대학교, 상과...
# 48  [현재, 한남, 대학교, 국제, 교육, 센터, 교수, 재직, 중이, 며, 대전, 지...
# 49  [보스턴, 대학, 교수, 이며, 매사추세츠, 공과대학, 디지털, 경제, 이니셔티브,...
#
#                                                   책소개  \
# 0   [창비, 장편소설, 상, 한국, 일보, 문학상, 수상, 작가, 정세랑, 두번째, 장...
# 1   [연속, 최, 장기, 베스트셀러, 만, 깨어있는, 독자, 선택, 한, 경제, 경영,...
# 2   [회계, 원리, 는, 모든, 회계, 기초, 입니다, 본, 서는, 회계, 관, 한, ...
# 3   [여기는, 잠들어야만, 입장, 할, 수, 있는, 달러, 구트, 꿈, 백화점, 입니다...
# 4   [마이클, 샌델, 만의, 신간, 공정하다는, 착각, 출, 간, 샌델, 기울어진, 사...
# 5   [만, 독자, 사로잡은, 달러, 구트, 꿈, 백화점, 두, 번째, 이야기, 어느덧,...
# 6   [최고, 재미, 감동, 선사, 하는, 힐링, 소설, 원조, 주요, 서점, 종합, 베...
# 7   [미국, 아마존, 금융, 사업, 분야, 위, 국내, 유명, 서점, 간, 종합, 베스...
# 8   [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 9   [밤, 시, 죽기, 전, 에만, 열리는, 마법, 도서관, 인생, 두, 번째, 기회,...
# 10  [한국, 정의, 열풍, 불러일으킨, 마이클, 샌델, 은, 구제, 금융, 대리, 출산...
# 11  [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 12  [안전가옥, 쇼트, 시리즈, 두, 번째, 책, 조예은, 작가, 단, 편집, 이다, ...
# 13  [우아한, 계보, 후지, 난, 겨울, 바이오, 센서, 만드는, 과학, 도, 였던, ...
# 14  [총, 권, 구성, 되어, 있으며, 원시, 사회, 에서부터, 청나라, 멸망, 중국,...
# 15  [책, 은, 국제, 경영, 관, 한, 이론, 서, 입니다, 국제, 경영, 기초, 적...
# 16  [김, 초엽, 첫, 장편소설, 간절히, 기다려, 온, 이야기, 이미, 폭넓은, 독자...
# 17                                                 []
# 18  [마케팅, 전략, 은, 커, 교수, 맥러, 그린, 교수, 공저, 한, 번역, 한, ...
# 19  [인터내셔널, 부커상, 산클레멘테, 문학상, 수상작, 전세계, 주목, 한, 한강, ...
# 20  [지적, 대화, 하기, 위해, 서, 깔려, 있어야, 하는, 가장, 기본, 지식, 시...
# 21  [현대인, 위, 한, 건강, 생활, 가이드, 시리즈, 좋은, 음식, 올바른, 식사,...
# 22  [방송, 계, 퓰리처상, 피버디상, 수상자, 룰루, 밀러, 사랑, 혼돈, 과학, 적...
# 23  [공감, 불능, 사회, 차가, 움, 녹이는, 아몬드, 매혹, 적, 인, 문체, 독특...
# 24                                                 []
# 25  [세계, 각국, 음식, 문화, 대한, 연구, 는, 인간, 의식, 구조, 삶, 방식,...
# 26  [번역본, 현대, 시, 지각, 이론, 입, 각하, 회화, 적, 재현, 역사, 심리,...
# 27  [미국, 아마존, 금융, 사업, 분야, 위, 국내, 유명, 서점, 간, 종합, 베스...
# 28  [똑같이, 우수한, 비, 전과, 전략, 수립, 하였음에도, 불구, 하고, 기업, 은...
# 29  [생각, 하면, 견딜, 수, 있나, 가슴, 활활, 일어나는, 불, 없다면, 기어이,...
# 30  [분석, 방법, 결과, 표, 작성, 해석, 방법, 논문, 초심자, 해야, 할, 하지...
# 31  [먼저, 죽는다면나는, 먹을, 거, 래야, 없이도, 죽지, 않고, 살, 수, 있어,...
# 32  [해리, 포터, 세대, 해리, 포터, 세대, 위, 한, 해리, 포터, 세대, 의한,...
# 33  [빅데이터, 시대, 이제, 는, 통계, 적, 사고, 경쟁력, 이다, 는, 살아가면서...
# 34  [다시, 정, 유정, 자기애, 늪, 빠진, 삶은, 위태, 로운, 압도, 적, 서사,...
# 35  [베스트셀러, 아들, 돈, 공부, 해야, 한다, 만, 부, 기념, 골드, 에디, 션...
# 36  [민족, 은, 민족, 정복, 지배, 대상, 전락, 하고, 말았는가, 원주민, 은, ...
# 37  [석유, 는, 데이터, 부동산, 은, 데이터, 센터, 코로나, 가속, 화, 한, 차...
# 38  [차, 산업혁명, 주인공, 은, 플랫폼, 축하, 거나, 활용, 하는, 자가, 될, ...
# 39  [받아들여지고, 있다는, 느낌, 이렇게, 슬프고도, 좋을, 줄, 이야, 브런치, 북...
# 40  [사랑, 입자, 타고, 낯선, 세계, 떠, 도, 는, 경이, 롭고, 아름다운, 우주...
# 41  [옥스퍼드, 대학, 입문, 총서, 시리즈, 심리학, 개론, 서, 두뇌, 대한, 과학...
# 42  [백, 감싸안으며, 이어지는, 사랑, 숨, 기록, 쇼코, 미소, 내게, 무, 해한,...
# 43  [현실, 타협, 하는, 삶, 에서도, 행복, 만드는, 방법, 꿈꾸기에는, 불안하고,...
# 44  [세기, 가장, 큰, 영향력, 미친, 책, 컬, 지는, 침묵, 봄, 개정판, 이다,...
# 45  [피터슨, 돌아왔다, 전, 세계, 젊은이, 열광, 시킨, 인생, 법칙, 완결, 판,...
# 46  [분광분석, 분리, 분석, 첫, 단계, 로서, 기, 기분, 석, 학, 약학, 교육,...
# 47  [한국, 최고, 마르크스, 경제학자, 김수행, 교수, 듣는, 자본론, 특강, 자본론...
# 48  [버전, 담은, 첫, 교재, 강의, 경력, 깊고, 풍부한, 전문, 강, 사진, 시험...
# 49  [차, 산업혁명, 주인공, 은, 플랫폼, 축하, 거나, 활용, 하는, 자가, 될, ...
#
#                                                    목차  \
# 0                                  [지구, 한아, 뿐, 작가, 말]
# 1   [쇄, 기념, 개정, 증보, 판, 내면, 서, 프롤로그, 돈, 은, 인격, 체다, ...
# 2   [장, 회계, 기초, 이론, 절, 회계, 기초, 회, 계란, 인가, 회계, 정보, ...
# 3   [작가, 말, 프롤로그, 번째, 제자, 유서, 깊은, 가게, 주문, 하신, 꿈, 은...
# 4   [서론, 대학, 입시, 능력, 주의, 입시, 윤리, 능력, 지표, 따내기, 승자, ...
# 5   [프롤로그, 달러, 구트, 다락방, 장, 페니, 첫, 번째, 연봉, 협상, 장, 민...
# 6   [산, 해, 진미, 도시락, 제이, 에스, 오브, 제이, 에스, 삼각김밥, 용도, ...
# 7   [머리말, 람보르기니, 예언, 실현, 되다, 프롤로그, 부자, 되는, 길, 에는, ...
# 8                                                  []
# 9                                                  []
# 10  [책, 쏟아진, 찬사, 한국어, 판, 서, 문장, 정의, 란, 옳고, 그름, 판단,...
# 11                                                 []
# 12  [초대, 습지, 사랑, 칵테일, 러브, 좀비, 오버, 랩, 나이프, 나이프, 작품,...
# 13  [순례, 은, 돌아오지, 않는가, 스펙트럼, 공생, 가설, 빛, 속도, 갈, 수, ...
# 14  [발간, 즈음, 하여, 발, 간사, 꿈, 추구, 독자, 위해, 엮, 은, 중국, 역...
# 15  [글로벌화, 글로벌, 경영, 글로벌화, 글로벌, 경영, 이해, 글로벌, 화란, 인가...
# 16  [프롤로그, 장, 모스, 바나, 장, 프림, 빌리지, 장, 지구, 끝, 온실, 작가...
# 17  [프롤로그, 일제시대, 종교, 정책, 보천교, 보천교, 민족, 독립운동, 식, 민권...
# 18  [장, 마케팅, 이란, 인가, 절, 마케팅, 이란, 절, 마케팅, 탄생, 의미, 절...
# 19  [채식주의자, 몽고반점, 나무, 불꽃, 새로, 쓴, 작가, 말, 작가, 말, 수록,...
# 20  [프롤로그, 책, 읽는, 방법, 준비, 운동, 세계, 구조, 화, 판단, 중, 지,...
# 21  [개혁, 필요한, 이유, 식생활, 영성, 건강, 개혁, 셋째, 천사, 기별, 합당,...
# 22  [프롤로그, 별, 머리, 담근, 소년, 섬, 선지자, 신, 없는, 막간, 극, 꼬리...
# 23                                                 []
# 24  [교육, 시설, 건축, 위, 한, 설계, 이론, 유형, 학습, 생활, 위, 한, 공...
# 25  [식생활, 문화, 이해, 하기, 음식, 문화, 역사, 선사시대, 음식, 문화, 역사...
# 26  [서문, 서론, 심리학, 양식, 수수께끼, 부, 유사성, 한계, 빛, 으로부터, 물...
# 27  [머리말, 람보르기니, 예언, 실현, 되다, 프롤로그, 부자, 되는, 길, 에는, ...
# 28  [부, 실행, 력, 인가, 장, 실행, 력, 없는, 비전은, 비극, 이다, 경영, ...
# 29  [부, 새, 결정, 실, 폭설, 새, 남은, 빛, 나무, 부, 밤, 작별, 하지, ...
# 30  [논문, 통계, 분석, 기초, 편, 사용, 할까, 요, 누가, 활용, 하면, 좋을까...
# 31                                    [구의, 증명, 작가, 말]
# 32                                                 []
# 33  [기술통계학, 자료, 정리, 요약, 도표, 이용, 한, 자료, 정리, 그림, 이용,...
# 34  [부, 그녀, 오리, 장, 장, 장, 부, 그녀, 는, 일까, 장, 장, 장, 부,...
# 35  [책, 쏟아진, 찬사, 만, 부, 기념, 골드, 에디, 션, 서문, 지금, 는, 다...
# 36  [친애하는, 한국, 독자, 드리는, 편지, 제레드, 다이아몬드, 증보, 판, 부쳐,...
# 37  [프롤로그, 는, 은, 는, 준비, 해야, 하는가, 새로운, 부가, 오고, 인공, ...
# 38  [한국어, 판, 서문, 우려, 스러운, 한국, 플랫폼, 경쟁력, 머리말, 플랫폼, ...
# 39  [서점, 은, 모습, 이어야, 할까, 이제, 더, 는, 울, 지, 않아도, 된다오,...
# 40  [최후, 라이, 오니, 마리, 춤, 로라, 숨, 그림자, 오래된, 협약, 인지, 공...
# 41  [심리학, 이란, 인가, 공부, 할, 인가, 두뇌, 속, 들어오게, 되는가, 인지,...
# 42                             [부, 부, 부, 부, 부, 작가, 말]
# 43  [추천사, 청춘, 한, 줄기, 빛, 될, 수, 있다면, 청춘, 머뭇거리, 기, 에는...
# 44  [감사, 글, 서문, 린다, 리, 내일, 위, 한, 우화, 참아야, 하는, 의무, ...
# 45  [법칙, 기존, 제도, 창의, 적, 변화, 함부로, 깎아내리지, 마라, 법칙, 내,...
# 46  [장, 분광분석법, 장, 분리, 분석, 법, 장, 전기화학, 분석, 법, 장, 원료...
# 47  [자본론, 대하, 자본주의, 사회, 는, 사라지지, 않을까, 인류, 경제, 사회, ...
# 48  [머리말, 시험, 소개, 시험, 인터페이스, 안내, 책, 학습, 방법, 목차, 화면...
# 49  [한국어, 판, 서문, 우려, 스러운, 한국, 플랫폼, 경쟁력, 머리말, 플랫폼, ...
#
#                                                 출판사서평  \
# 0   [점점, 줄어드는, 페이지, 보며, 아쉬워, 무거워진, 눈꺼풀, 참으며, 책, 읽는...
# 1   [는, 정말, 필요한, 나누려는, 사람, 이다, 최근, 사이, 수만, 명의, 사람,...
# 2   [회계, 원리, 회계, 원리, 는, 모든, 회계, 기초, 입니다, 본, 서는, 회계...
# 3   [텀블벅, 펀딩, 달성, 출, 간, 주, 연속, 종합, 베스트셀러, 위, 독자, 별...
# 4   [능력, 주의, 는, 공정하게, 작동, 하는가, 공정함, 정의, 란, 공식, 은, ...
# 5   [내내, 베스트셀러, 위, 독자, 뽑은, 최고, 힐링, 판타지, 잠들어야만, 입장,...
# 6   [원, 플러스, 원, 기쁨, 삼각김밥, 모양, 슬픔, 만, 원, 번의, 폭소, 터지...
# 7   [부자, 되기, 플랜, 속지, 마라, 지금, 까지의, 부자, 되기, 책, 이야기, ...
# 8   [회복, 연민, 대한, 강력한, 이야기, 버락, 오바마, 미국, 전, 대통령, 전,...
# 9   [영국, 아마존, 종합, 베스트셀러, 위, 미국, 아마존, 뉴욕타임스, 선데이타임스...
# 10  [정의, 둘러싼, 위대한, 철학자, 과의, 대화, 글로벌, 금융, 위기, 이후, 억...
# 11  [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 12  [토록, 생생한, 어둠, 감정, 은, 곧잘, 무시, 당한다, 여성, 이라서, 자식,...
# 13  [젊은, 소설가, 첫, 작품집, 이라고는, 믿기지, 않을, 정도, 매끄럽게, 이어지...
# 14  [일반, 독자, 위, 한, 중국, 역사, 문화, 집대성, 한, 백과사전, 중국, 저...
# 15                                                 []
# 16  [악마, 식물, 내, 정원, 자라고, 있는데, 거, 멸망, 징조, 아니야, 덩굴식물...
# 17                                                 []
# 18                                                 []
# 19  [폭력, 아름다, 움, 처절한, 공존, 새롭게, 읽히는, 한강, 소설, 힘년, 창비...
# 20  [만, 부, 밀리언셀러, 지대, 넓, 얕, 최초, 개정, 증보, 판, 지적, 대화,...
# 21                                                 []
# 22  [워싱턴포스트, 북, 라이엇, 내서, 널퍼, 블릭, 라디오, 시카고, 트리뷴, 스미...
# 23  [감정, 느끼지, 못, 하는, 소년, 특별한, 성장, 아몬드, 주인공, 윤재, 는,...
# 24                                                 []
# 25  [식생활, 이란, 인간, 생활, 중, 생명, 유지, 생체, 활동, 필요한, 영양분,...
# 26  [심리학, 철학, 문, 화사, 전반, 가로지르는, 곰, 브리, 치, 미술사, 연구,...
# 27  [부자, 되기, 플랜, 속지, 마라, 지금, 까지의, 부자, 되기, 책, 이야기, ...
# 28                                                 []
# 29  [이상하지, 눈, 은, 하늘, 저런, 게, 내려오지, 작별, 지, 않는다는, 소설가...
# 30  [논문, 통계, 분석, 기초, 편, 에서는, 통계, 분석, 하기, 전, 알아야, 하...
# 31  [상상, 가능, 케, 하는, 사랑, 그런, 사랑, 가능, 케, 하는, 상상, 여자,...
# 32  [해리, 포터, 키즈, 완벽하게, 구현, 한, 롤링, 마법, 세계, 시대, 가장, ...
# 33                                                 []
# 34  [행복, 은, 덧셈, 아니야, 행복, 은, 뺄셈, 이야, 완전해질, 불행, 가능성,...
# 35  [경제, 는, 사람, 사이, 실생활, 밀착, 형, 경제, 수업, 아들, 돈, 공부,...
# 36  [인류, 문명, 수수께끼, 새로운, 풀어, 낸, 명, 개정, 신판, 특별, 증보, ...
# 37  [석유, 는, 데이터, 부동산, 은, 데이터, 센터, 코로나, 가속, 화, 한, 차...
# 38  [세계, 적, 인, 석, 학, 저술, 한, 플랫폼, 비즈니스, 안내서, 포브스, 선...
# 39  [먼저, 읽은, 독자, 요청, 종이, 책, 다시, 태어난, 소설, 출, 간, 전자책...
# 40  [사랑, 끝내, 이해, 할, 수, 없는, 에게도, 있지, 않나요, 빛, 속도, 갈,...
# 41                                                 []
# 42  [슬픔, 위로, 하고, 감싸주는, 더, 큰, 슬픔, 힘, 오정희, 소설가, 증조, ...
# 43  [꿈, 현실, 사이, 방황, 하는, 대를, 위, 한, 청춘, 사용설명서, 꿈, 좇자...
# 44  [세상, 바꾼, 인물, 세상, 변화, 시킨, 책, 더, 설명, 필요, 없는, 세기,...
# 45  [시대, 가장, 논쟁, 적, 이고, 영향력, 있는, 지식인, 가지, 인생, 법칙, ...
# 46  [의약품, 기, 기분, 석, 학, 분권, 한, 후의, 첫, 번째, 개정, 분권, 후...
# 47  [한국, 최고, 마르크스, 경제학자, 김수행, 교수, 듣는, 자본론, 특강, 최고,...
# 48                                                 []
# 49  [세계, 적, 인, 석, 학, 저술, 한, 플랫폼, 비즈니스, 안내서, 포브스, 선...
#
#                                                   추천사  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [역시, 마이클, 샌델답다, 에는, 시대, 가장, 예민한, 이슈, 수술, 메스, 대...
# 5                                                  []
# 6   [서울역, 홈리스, 지내면서도, 안위, 보다는, 지갑, 잃어버린, 낯선, 부인, 안...
# 7   [부동산, 스터디, 우석, 신사임당, 이상한, 리뷰, 앨리스, 단, 희, 인, 플루...
# 8   [올해, 최고, 책, 록산, 게이, 작가, 세기, 견뎌내고, 번영, 이룬, 재일한국...
# 9                                                  []
# 10                                                 []
# 11  [올해, 최고, 책, 록산, 게이, 작가, 세기, 견뎌내고, 번영, 이룬, 재일한국...
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16  [간절히, 원, 해온, 은, 울, 고, 난, 뒤, 에야, 알, 게, 되는, 걸까, ...
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22  [내, 맘대로, 올해, 책, 물고기, 는, 존재, 하지, 않는다, 책장, 덮는, 순...
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 27  [부동산, 스터디, 우석, 신사임당, 이상한, 리뷰, 앨리스, 단, 희, 인, 플루...
# 28                                                 []
# 29  [작가, 소재, 택하, 는, 아니라, 반, 대, 일지, 도, 모른다는, 생각, 한강...
# 30                                                 []
# 31                                                 []
# 32                                                 []
# 33                                                 []
# 34                                                 []
# 35  [한때, 좋은, 대학, 만, 가면, 앞길, 훤히, 열릴, 이라는, 믿음, 진실, 이...
# 36                                                 []
# 37                                                 []
# 38  [세기, 후반, 등장, 한, 디지털, 혁명, 인터넷, 혁명, 은, 모바일, 혁명, ...
# 39  [내, 맘대로, 올해, 책, 모자라지도, 하지도, 않은, 적당한, 온도, 따뜻함과,...
# 40  [김, 초엽, 눈부신, 데뷔, 이후, 줄곧, 두, 번째, 소설, 집, 기다려, 왔다...
# 41                                                 []
# 42  [태생, 지를, 빌려, 삼천이, 새, 비, 서로, 부르며, 한, 세상, 살, 냈던,...
# 43  [책, 추천사, 의뢰, 받으면서, 떠오른, 생각, 은, 였습니다, 청춘, 한, 줄기...
# 44                                                 []
# 45  [지금, 세상, 은, 조던, 피터슨, 필요, 한다, 더글러스, 머리, 유럽, 죽음,...
# 46                                                 []
# 47                                                 []
# 48                                                 []
# 49  [세기, 후반, 등장, 한, 디지털, 혁명, 인터넷, 혁명, 은, 모바일, 혁명, ...
#
#                                                서평+추천사
# 0   [점점, 줄어드는, 페이지, 보며, 아쉬워, 무거워진, 눈꺼풀, 참으며, 책, 읽는...
# 1   [는, 정말, 필요한, 나누려는, 사람, 이다, 최근, 사이, 수만, 명의, 사람,...
# 2   [회계, 원리, 회계, 원리, 는, 모든, 회계, 기초, 입니다, 본, 서는, 회계...
# 3   [텀블벅, 펀딩, 달성, 출, 간, 주, 연속, 종합, 베스트셀러, 위, 독자, 별...
# 4   [능력, 주의, 는, 공정하게, 작동, 하는가, 공정함, 정의, 란, 공식, 은, ...
# 5   [내내, 베스트셀러, 위, 독자, 뽑은, 최고, 힐링, 판타지, 잠들어야만, 입장,...
# 6   [원, 플러스, 원, 기쁨, 삼각김밥, 모양, 슬픔, 만, 원, 번의, 폭소, 터지...
# 7   [부자, 되기, 플랜, 속지, 마라, 지금, 까지의, 부자, 되기, 책, 이야기, ...
# 8   [회복, 연민, 대한, 강력한, 이야기, 버락, 오바마, 미국, 전, 대통령, 전,...
# 9   [영국, 아마존, 종합, 베스트셀러, 위, 미국, 아마존, 뉴욕타임스, 선데이타임스...
# 10  [정의, 둘러싼, 위대한, 철학자, 과의, 대화, 글로벌, 금융, 위기, 이후, 억...
# 11  [역사, 는, 버렸지만, 상관없다, 역사, 외면, 당, 한, 재일조선인, 가족, 대...
# 12  [토록, 생생한, 어둠, 감정, 은, 곧잘, 무시, 당한다, 여성, 이라서, 자식,...
# 13  [젊은, 소설가, 첫, 작품집, 이라고는, 믿기지, 않을, 정도, 매끄럽게, 이어지...
# 14  [일반, 독자, 위, 한, 중국, 역사, 문화, 집대성, 한, 백과사전, 중국, 저...
# 15                                                 []
# 16  [악마, 식물, 내, 정원, 자라고, 있는데, 거, 멸망, 징조, 아니야, 덩굴식물...
# 17                                                 []
# 18                                                 []
# 19  [폭력, 아름다, 움, 처절한, 공존, 새롭게, 읽히는, 한강, 소설, 힘년, 창비...
# 20  [만, 부, 밀리언셀러, 지대, 넓, 얕, 최초, 개정, 증보, 판, 지적, 대화,...
# 21                                                 []
# 22  [워싱턴포스트, 북, 라이엇, 내서, 널퍼, 블릭, 라디오, 시카고, 트리뷴, 스미...
# 23  [감정, 느끼지, 못, 하는, 소년, 특별한, 성장, 아몬드, 주인공, 윤재, 는,...
# 24                                                 []
# 25  [식생활, 이란, 인간, 생활, 중, 생명, 유지, 생체, 활동, 필요한, 영양분,...
# 26  [심리학, 철학, 문, 화사, 전반, 가로지르는, 곰, 브리, 치, 미술사, 연구,...
# 27  [부자, 되기, 플랜, 속지, 마라, 지금, 까지의, 부자, 되기, 책, 이야기, ...
# 28                                                 []
# 29  [이상하지, 눈, 은, 하늘, 저런, 게, 내려오지, 작별, 지, 않는다는, 소설가...
# 30  [논문, 통계, 분석, 기초, 편, 에서는, 통계, 분석, 하기, 전, 알아야, 하...
# 31  [상상, 가능, 케, 하는, 사랑, 그런, 사랑, 가능, 케, 하는, 상상, 여자,...
# 32  [해리, 포터, 키즈, 완벽하게, 구현, 한, 롤링, 마법, 세계, 시대, 가장, ...
# 33                                                 []
# 34  [행복, 은, 덧셈, 아니야, 행복, 은, 뺄셈, 이야, 완전해질, 불행, 가능성,...
# 35  [경제, 는, 사람, 사이, 실생활, 밀착, 형, 경제, 수업, 아들, 돈, 공부,...
# 36  [인류, 문명, 수수께끼, 새로운, 풀어, 낸, 명, 개정, 신판, 특별, 증보, ...
# 37  [석유, 는, 데이터, 부동산, 은, 데이터, 센터, 코로나, 가속, 화, 한, 차...
# 38  [세계, 적, 인, 석, 학, 저술, 한, 플랫폼, 비즈니스, 안내서, 포브스, 선...
# 39  [먼저, 읽은, 독자, 요청, 종이, 책, 다시, 태어난, 소설, 출, 간, 전자책...
# 40  [사랑, 끝내, 이해, 할, 수, 없는, 에게도, 있지, 않나요, 빛, 속도, 갈,...
# 41                                                 []
# 42  [슬픔, 위로, 하고, 감싸주는, 더, 큰, 슬픔, 힘, 오정희, 소설가, 증조, ...
# 43  [꿈, 현실, 사이, 방황, 하는, 대를, 위, 한, 청춘, 사용설명서, 꿈, 좇자...
# 44  [세상, 바꾼, 인물, 세상, 변화, 시킨, 책, 더, 설명, 필요, 없는, 세기,...
# 45  [시대, 가장, 논쟁, 적, 이고, 영향력, 있는, 지식인, 가지, 인생, 법칙, ...
# 46  [의약품, 기, 기분, 석, 학, 분권, 한, 후의, 첫, 번째, 개정, 분권, 후...
# 47  [한국, 최고, 마르크스, 경제학자, 김수행, 교수, 듣는, 자본론, 특강, 최고,...
# 48                                                 []
# 49  [세계, 적, 인, 석, 학, 저술, 한, 플랫폼, 비즈니스, 안내서, 포브스, 선...

# %%
df.to_excel('삼육대 전처리.xlsx',index=False)

# %% [markdown]
# # 9 토픽 모델링 LDA

# %% [markdown]
# - 일관성 점수가 높은 모델은 주제 간의 일관성이 높아 의미 있는 토픽을 잘 나타내는 경향
